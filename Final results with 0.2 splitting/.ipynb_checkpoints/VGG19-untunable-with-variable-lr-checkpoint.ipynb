# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Set up environment

# %%
# Just delete the output of loading the files because it was very big

import math, re, os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from kaggle_datasets import KaggleDatasets
from tensorflow import keras
from functools import partial
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

##import tensorflow.keras.backend as K

from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization, MaxPool2D
from keras.optimizers import SGD
import keras

import h5py

from keras.callbacks import ModelCheckpoint

from keras import metrics


print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.2.0

# %% [markdown]
# # Detect TPU
# What we're doing with our code here is making sure that we'll be sending our data across a TPU. What you're looking for is a printout of `Number of replicas: 8`, corresponding to the 8 cores of a TPU. If your printout instead says `Number of replicas: 1` you likely do not have TPUs enabled in your notebook.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Device: grpc://10.0.0.2:8470
# Number of replicas: 8

# %% [markdown]
# # Set up variables
# We'll set up some of our variables for our notebook here.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path('cassava-leaf-disease-classification')     

##../input/cassava-leaf-disease-classification

BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [512, 512]
CLASSES = ['0', '1', '2', '3', '4']
LABELS = [0,1,2,3,4]
##EPOCHS = 300
EPOCHS = 300

# %%
# No. of batched images for each batch 
BATCH_SIZE
# Out:
# 128

# %%
# Loading the data file names with labels
df = pd.read_csv(GCS_PATH + '/train.csv')

# %%
# Images and Labels
X = df.loc[:,'image_id']
y = df.loc[:,'label']
# getting the values to count each category 
count_labels=y.values

# %%
# Counting each types of the 5 labels 

CBB = 0
CBSD = 0
CGM = 0
CMD = 0
Healthy = 0

for label in count_labels:
    if label == 0:
        CBB += 1
    elif label == 1:
        CBSD  += 1
    elif label == 2:
        CGM  += 1
    elif label == 3:
        CMD  += 1
    else:
        Healthy +=1


print("The number of CBB = ",CBB )
print("The number of CBSD = ",CBSD)
print("The number of CGM = ",CGM )
print("The number of CMD = ",CMD)
print("The number of Healthy = ",Healthy)
# Out:
# The number of CBB =  1087
# The number of CBSD =  2189
# The number of CGM =  2386
# The number of CMD =  13158
# The number of Healthy =  2577

# %%
No_Of_Labels = {'0': 1087, '1': 2189, '2': 2386, '3': 13158, '4': 2577}

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.bar(No_Of_Labels.keys(),No_Of_Labels.values())
plt.show()

# %% [markdown]
# # Load the data
#
# The data we're working with have been formatted into `TFRecords`, which are a format for storing a sequence of binary records. `TFRecords` work _really_ well with TPUs, and allow us to send a small number of large files across the TPU for processing.
#
# ## Decode the data
#
# In the code chunk below we'll set up a series of functions that allow us to convert our images into tensors so that we can utilize them in our model. We'll also normalize our data. Our images are using a "Red, Blue, Green (RBG)" scale that has a range of [0, 255], and by normalizing it we'll set each pixel's value to a number in the range of [0, 1].
#
# ## Use the data as soon as it streams in
#
# We'll use the following function to load our dataset. One of the advantages of a TPU is that we can run multiple files across the TPU at once, and this accounts for the speed advantages of using a TPU. To capitalize on that, we want to make sure that we're using data as soon as it streams in, rather than creating a data streaming bottleneck.

# %%
## Loading , reading and decoding images from TFRecords

## will be used to load the training data and the validation data

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example, labeled):
    tfrecord_format = {
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.int64)
    } if labeled else {
        "image": tf.io.FixedLenFeature([], tf.string),
        "image_name": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    if labeled:
        label = tf.cast(example['target'], tf.int32)
        return image, label
    idnum = example['image_name']
    return image, idnum

def load_dataset(filenames, labeled=True, ordered=False):
    ignore_order = tf.data.Options() ## Turn off optimization 
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed, ## Turn off optimization (or ordered)
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(partial(read_tfrecord, labeled=labeled), num_parallel_calls=AUTOTUNE)
    return dataset

# %% [markdown]
# ## Adding in augmentations
#
# Augmentation on the fly using dataset.prefetch(AUTO) after calling data_augment(image, label)
#
# Thanks to the dataset.prefetch(AUTO) statement in the following function this happens essentially for free on TPU.
# Data pipeline code is executed on the "CPU" part of the TPU while the TPU itself is computing gradients.

# %%
## Augmentation on the fly using dataset.prefetch(AUTO) after calling data_augment(image, label)

def data_augment(image, label):
    # Thanks to the dataset.prefetch(AUTO) statement in the following function this happens essentially for free on TPU. 
    # Data pipeline code is executed on the "CPU" part of the TPU while the TPU itself is computing gradients.
    
    ## Manual Augmentation using tf.images library for Augmentation
    
    ## Randomly choose between features to be applied in the Augmentation
    
    choice = np.random.randint(5)
    if choice == 0:
        image = tf.image.flip_left_right(image)
    elif choice == 1:
        image = tf.image.flip_up_down(image)
    elif choice == 2:
        image = tf.image.random_flip_left_right(image)
    elif choice == 3:
        image = tf.image.random_flip_up_down(image)
    else:
        image = tf.image.rot90(image)
    
    ##else:
    ##    return image, label
    
    return image, label

## other features could be applied for Augmentation
'''
elif choice == 5:
        image = tf.image.transpose(image)
    elif choice == 6:
        image = tf.image.adjust_brightness(image, delta=0.1)
    elif choice == 7:
        image = tf.image.adjust_contrast(image, 2)
    elif choice == 8:
        image = tf.image.adjust_gamma(image, 0.2)
    elif choice == 9:
        image = tf.image.random_brightness(image, 0.2)
    elif choice == 10:
        image = tf.image.random_contrast(image, 0.2, 0.5)
    elif choice == 11:
        image = tf.image.rgb_to_grayscale(image)
    else:
        image = tf.image.adjust_hue(image, 0.2)
'''

# %% [markdown]
# # Splitting the data
#
# Because our data consists of `training` and `test` images only, we're going to split our `training` data into `training` and `validation` data using the `train_test_split()` function.

# %%
TRAINING_FILENAMES, VALID_FILENAMES = train_test_split(
    tf.io.gfile.glob(GCS_PATH + '/train_tfrecords/ld_train*.tfrec'),
    test_size=0.2, random_state=5
)

TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test_tfrecords/ld_test*.tfrec')

# %%
VALID_FILENAMES
# Out:
# ['gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train05-1338.tfrec',
#  'gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train01-1338.tfrec',
#  'gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train07-1338.tfrec',
#  'gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train02-1338.tfrec']

# %% [markdown]
# ## Define data loading methods
# The following functions will be used to load our `training`, `validation`, and `test` datasets, as well as print out the number of images in each dataset.

# %%
## Loading, Augmentation , shuffling batching and prefetching for dataset and call training, validation and testing

def get_training_dataset():
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True)  
    dataset = dataset.map(data_augment, num_parallel_calls=AUTOTUNE)  ## Augmentation
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048) ## shuffling the dataset 
    dataset = dataset.batch(BATCH_SIZE) ## put the dataset as batches
    dataset = dataset.prefetch(AUTOTUNE) ## used to help Augmentation to be on the fly as we said the Augmentation cell 
    return dataset

def get_validation_dataset(ordered=False):
    dataset = load_dataset(VALID_FILENAMES, labeled=True, ordered=ordered)
    ##dataset = dataset.map(data_augment, num_parallel_calls=AUTOTUNE) 
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

def get_test_dataset(ordered=False):
    dataset = load_dataset(TEST_FILENAMES, labeled=False, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

# %%
## counting the number of dataset in each category (training and validation)

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALID_FILENAMES)
NUM_TEST_IMAGES = count_data_items(TEST_FILENAMES)

print('Dataset: {} training images, {} validation images, {} (unlabeled) test images'.format(
    NUM_TRAINING_IMAGES, NUM_VALIDATION_IMAGES, NUM_TEST_IMAGES))
# Out:
# Dataset: 18721 training images, 2676 validation images, 1 (unlabeled) test images

# %% [markdown]
# # Building the model
# ## Learning rate schedule
# We learned about learning rates in the **[Intro to Deep Learning: Stochastic Gradient Descent](https://www.kaggle.com/ryanholbrook/stochastic-gradient-descent)** lesson, and here I've created a learning rate schedule mostly using the defaults in the **[Keras Exponential Decay Learning Rate Scheduler](https://keras.io/api/optimizers/learning_rate_schedules/exponential_decay/)** documentation (I did change the `initial_learning_rate`. You can adjust the learning rate scheduler below, and read more about the other types of schedulers available to you in the **[Keras learning rate schedules API](https://keras.io/api/optimizers/learning_rate_schedules/)**.

# %%
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-5, 
    decay_steps=10000, 
    decay_rate=0.9)

# %%
# example of loading the vgg19 model
from keras.applications.vgg19 import VGG19
# load model
model = VGG19()
# summarize the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 4s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Building our model
# In order to ensure that our model is trained on the TPU, we build it using `with strategy.scope()`.
#
# This model was built using transfer learning, meaning that we have a _pre-trained model_ (ResNet50) as our base model and then the customizable model built using `tf.keras.Sequential`. If you're new to transfer learning I recommend setting `base_model.trainable` to **False**, but _do_ encourage you to change which base model you're using (more options are available in the **[`tf.keras.applications` Module](https://www.tensorflow.org/api_docs/python/tf/keras/applications)** documentation) as well iterate on the custom model.
#
# Note that we're using `sparse_categorical_crossentropy` as our loss function, because we did _not_ one-hot encode our labels.

# %% [markdown]
# # Putting Tranfser learning layer
#
# # Parameters that will not changed during comparisons
#
# We just include the cnn layers (include_top=False)
#
# Getting the weights of the pretrained model (weights="imagenet)

# %% [markdown]
# # Parameters that will be changed during comparisons
#
# Transfer layer VGG19
#
# The parameters are untunable (trainable = FALSE)
#
# Variable training rate with lr_scheduler
#
# Putting 5 Linear connected layers + 1 for softmax output

# %%
from keras.applications.vgg19 import preprocess_input

#tf.keras.applications.vgg19.preprocess_input


with strategy.scope():       
    ##img_adjust_layer = tf.keras.layers.Lambda(tf.keras.applications.vgg16.preprocess_input, input_shape=[512,512, 3])
    
    base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_tensor= None,
    input_shape=[512,512, 3],
    pooling=None,
    classes=5,
    classifier_activation="softmax")
    
    base_model.trainable = False
    
    
    model = tf.keras.Sequential([
        tf.keras.layers.BatchNormalization(renorm=True),
        ##img_adjust_layer,
        base_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=4096,activation="relu"),
        tf.keras.layers.Dense(units=4096,activation="relu"),
        tf.keras.layers.Dense(units=1000,activation="relu"),
        tf.keras.layers.Dense(units=500,activation="relu"),
        tf.keras.layers.Dense(units=100,activation="relu"),
        tf.keras.layers.Dense(units=5, activation="softmax") 
        
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_scheduler, epsilon=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy'])
        

'''
        metrics2=['categorical_accuracy',
                           tf.keras.metrics.Precision(name='Precision'),
                           tf.keras.metrics.Recall(name='Recall')])
                           
                           'sparse_categorical_accuracy'
                           metrics=['sparse_categorical_accuracy'])
                            metrics=['sparse_categorical_accuracy',tf.keras.metrics.AUC()])
'''
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# "\n        metrics2=['categorical_accuracy',\n                           tf.keras.metrics.Precision(name='Precision'),\n                           tf.keras.metrics.Recall(name='Recall')])\n                           \n                           'sparse_categorical_accuracy'\n                           metrics=['sparse_categorical_accuracy'])\n                            metrics=['sparse_categorical_accuracy',tf.keras.metrics.AUC()])\n"

# %% [markdown]
# # Train the model
# As our model is training you'll see a printout for each epoch, and can also monitor TPU usage by clicking on the TPU metrics in the toolbar at the top right of your notebook.

# %%
# load data
train_dataset = get_training_dataset()
valid_dataset = get_validation_dataset()

# %%
from keras.callbacks import CSVLogger

##csv_logger = CSVLogger('training.log', separator=',', append=False)

# %% [markdown]
# # CallBacks
#
# EarlyStopping : stop early after "patience" number where there is no improvement in the learning
#
# ModelCheckpoint : to save the model
#
# CSVLogger : to save the history of the model after each epoic

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

keras_callbacks   = [EarlyStopping(monitor='val_loss', patience=30, mode='min', min_delta=0.0001),
    ModelCheckpoint('mymodel.h5', monitor='val_loss', verbose=1,
    save_best_only=True, save_weights_only=True, mode='auto', period=1),
    CSVLogger('training.log', separator=',', append=False)
    
]

##save_best_only=True

# %% [markdown]
# # Train the model

# %%
STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE
VALID_STEPS = NUM_VALIDATION_IMAGES // BATCH_SIZE

history = model.fit(train_dataset, 
                    steps_per_epoch=STEPS_PER_EPOCH, 
                    epochs=EPOCHS,
                    validation_data=valid_dataset,
                    validation_steps=VALID_STEPS,
                    callbacks=keras_callbacks)
                   

##model.save('mymodel.h5')
# Out:
# Epoch 1/300
# 125/125 [==============================] - ETA: 0s - loss: 1.3132 - sparse_categorical_accuracy: 0.5751
# Epoch 00001: val_loss improved from inf to 1.17972, saving model to mymodel.h5
# 125/125 [==============================] - 50s 401ms/step - loss: 1.3132 - sparse_categorical_accuracy: 0.5751 - val_loss: 1.1797 - val_sparse_categorical_accuracy: 0.6101
# Epoch 2/300
# 125/125 [==============================] - ETA: 0s - loss: 1.1531 - sparse_categorical_accuracy: 0.6176
# Epoch 00002: val_loss improved from 1.17972 to 1.15008, saving model to mymodel.h5
# 125/125 [==============================] - 38s 305ms/step - loss: 1.1531 - sparse_categorical_accuracy: 0.6176 - val_loss: 1.1501 - val_sparse_categorical_accuracy: 0.6101
# Epoch 3/300
# 125/125 [==============================] - ETA: 0s - loss: 1.1311 - sparse_categorical_accuracy: 0.6169
# Epoch 00003: val_loss improved from 1.15008 to 1.12255, saving model to mymodel.h5
# 125/125 [==============================] - 38s 307ms/step - loss: 1.1311 - sparse_categorical_accuracy: 0.6169 - val_loss: 1.1226 - val_sparse_categorical_accuracy: 0.6101
# Epoch 4/300
# 125/125 [==============================] - ETA: 0s - loss: 1.1018 - sparse_categorical_accuracy: 0.6154
# Epoch 00004: val_loss improved from 1.12255 to 1.08741, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 1.1018 - sparse_categorical_accuracy: 0.6154 - val_loss: 1.0874 - val_sparse_categorical_accuracy: 0.6101
# Epoch 5/300
# 125/125 [==============================] - ETA: 0s - loss: 1.0583 - sparse_categorical_accuracy: 0.6183
# Epoch 00005: val_loss improved from 1.08741 to 1.04580, saving model to mymodel.h5
# 125/125 [==============================] - 38s 308ms/step - loss: 1.0583 - sparse_categorical_accuracy: 0.6183 - val_loss: 1.0458 - val_sparse_categorical_accuracy: 0.6103
# Epoch 6/300
# 125/125 [==============================] - ETA: 0s - loss: 1.0155 - sparse_categorical_accuracy: 0.6234
# Epoch 00006: val_loss improved from 1.04580 to 0.99939, saving model to mymodel.h5
# 125/125 [==============================] - 38s 307ms/step - loss: 1.0155 - sparse_categorical_accuracy: 0.6234 - val_loss: 0.9994 - val_sparse_categorical_accuracy: 0.6244
# Epoch 7/300
# 125/125 [==============================] - ETA: 0s - loss: 0.9734 - sparse_categorical_accuracy: 0.6379
# Epoch 00007: val_loss improved from 0.99939 to 0.95632, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.9734 - sparse_categorical_accuracy: 0.6379 - val_loss: 0.9563 - val_sparse_categorical_accuracy: 0.6479
# Epoch 8/300
# 125/125 [==============================] - ETA: 0s - loss: 0.9248 - sparse_categorical_accuracy: 0.6559
# Epoch 00008: val_loss improved from 0.95632 to 0.91794, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.9248 - sparse_categorical_accuracy: 0.6559 - val_loss: 0.9179 - val_sparse_categorical_accuracy: 0.6543
# Epoch 9/300
# 125/125 [==============================] - ETA: 0s - loss: 0.8979 - sparse_categorical_accuracy: 0.6626
# Epoch 00009: val_loss improved from 0.91794 to 0.88626, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.8979 - sparse_categorical_accuracy: 0.6626 - val_loss: 0.8863 - val_sparse_categorical_accuracy: 0.6673
# Epoch 10/300
# 125/125 [==============================] - ETA: 0s - loss: 0.8632 - sparse_categorical_accuracy: 0.6755
# Epoch 00010: val_loss improved from 0.88626 to 0.85999, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.8632 - sparse_categorical_accuracy: 0.6755 - val_loss: 0.8600 - val_sparse_categorical_accuracy: 0.6793
# Epoch 11/300
# 125/125 [==============================] - ETA: 0s - loss: 0.8438 - sparse_categorical_accuracy: 0.6817
# Epoch 00011: val_loss improved from 0.85999 to 0.83693, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.8438 - sparse_categorical_accuracy: 0.6817 - val_loss: 0.8369 - val_sparse_categorical_accuracy: 0.6846
# Epoch 12/300
# 125/125 [==============================] - ETA: 0s - loss: 0.8229 - sparse_categorical_accuracy: 0.6906
# Epoch 00012: val_loss improved from 0.83693 to 0.81850, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.8229 - sparse_categorical_accuracy: 0.6906 - val_loss: 0.8185 - val_sparse_categorical_accuracy: 0.6932
# Epoch 13/300
# 125/125 [==============================] - ETA: 0s - loss: 0.8034 - sparse_categorical_accuracy: 0.6959
# Epoch 00013: val_loss improved from 0.81850 to 0.80507, saving model to mymodel.h5
# 125/125 [==============================] - 39s 313ms/step - loss: 0.8034 - sparse_categorical_accuracy: 0.6959 - val_loss: 0.8051 - val_sparse_categorical_accuracy: 0.6940
# Epoch 14/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7879 - sparse_categorical_accuracy: 0.7001
# Epoch 00014: val_loss improved from 0.80507 to 0.78854, saving model to mymodel.h5
# 125/125 [==============================] - 38s 307ms/step - loss: 0.7879 - sparse_categorical_accuracy: 0.7001 - val_loss: 0.7885 - val_sparse_categorical_accuracy: 0.7037
# Epoch 15/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7788 - sparse_categorical_accuracy: 0.7045
# Epoch 00015: val_loss improved from 0.78854 to 0.77385, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.7788 - sparse_categorical_accuracy: 0.7045 - val_loss: 0.7738 - val_sparse_categorical_accuracy: 0.7128
# Epoch 16/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7666 - sparse_categorical_accuracy: 0.7082
# Epoch 00016: val_loss improved from 0.77385 to 0.76118, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.7666 - sparse_categorical_accuracy: 0.7082 - val_loss: 0.7612 - val_sparse_categorical_accuracy: 0.7157
# Epoch 17/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7509 - sparse_categorical_accuracy: 0.7134
# Epoch 00017: val_loss improved from 0.76118 to 0.74941, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.7509 - sparse_categorical_accuracy: 0.7134 - val_loss: 0.7494 - val_sparse_categorical_accuracy: 0.7208
# Epoch 18/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7429 - sparse_categorical_accuracy: 0.7204
# Epoch 00018: val_loss improved from 0.74941 to 0.74920, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.7429 - sparse_categorical_accuracy: 0.7204 - val_loss: 0.7492 - val_sparse_categorical_accuracy: 0.7277
# Epoch 19/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7325 - sparse_categorical_accuracy: 0.7246
# Epoch 00019: val_loss improved from 0.74920 to 0.72793, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.7325 - sparse_categorical_accuracy: 0.7246 - val_loss: 0.7279 - val_sparse_categorical_accuracy: 0.7252
# Epoch 20/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7193 - sparse_categorical_accuracy: 0.7303
# Epoch 00020: val_loss improved from 0.72793 to 0.71846, saving model to mymodel.h5
# 125/125 [==============================] - 38s 307ms/step - loss: 0.7193 - sparse_categorical_accuracy: 0.7303 - val_loss: 0.7185 - val_sparse_categorical_accuracy: 0.7309
# Epoch 21/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7117 - sparse_categorical_accuracy: 0.7302
# Epoch 00021: val_loss improved from 0.71846 to 0.70936, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.7117 - sparse_categorical_accuracy: 0.7302 - val_loss: 0.7094 - val_sparse_categorical_accuracy: 0.7370
# Epoch 22/300
# 125/125 [==============================] - ETA: 0s - loss: 0.7043 - sparse_categorical_accuracy: 0.7335
# Epoch 00022: val_loss improved from 0.70936 to 0.70194, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.7043 - sparse_categorical_accuracy: 0.7335 - val_loss: 0.7019 - val_sparse_categorical_accuracy: 0.7403
# Epoch 23/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6999 - sparse_categorical_accuracy: 0.7366
# Epoch 00023: val_loss improved from 0.70194 to 0.70177, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.6999 - sparse_categorical_accuracy: 0.7366 - val_loss: 0.7018 - val_sparse_categorical_accuracy: 0.7344
# Epoch 24/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6859 - sparse_categorical_accuracy: 0.7421
# Epoch 00024: val_loss improved from 0.70177 to 0.69921, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.6859 - sparse_categorical_accuracy: 0.7421 - val_loss: 0.6992 - val_sparse_categorical_accuracy: 0.7367
# Epoch 25/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6778 - sparse_categorical_accuracy: 0.7459
# Epoch 00025: val_loss improved from 0.69921 to 0.68300, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6778 - sparse_categorical_accuracy: 0.7459 - val_loss: 0.6830 - val_sparse_categorical_accuracy: 0.7435
# Epoch 26/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6837 - sparse_categorical_accuracy: 0.7441
# Epoch 00026: val_loss improved from 0.68300 to 0.67621, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6837 - sparse_categorical_accuracy: 0.7441 - val_loss: 0.6762 - val_sparse_categorical_accuracy: 0.7456
# Epoch 27/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6718 - sparse_categorical_accuracy: 0.7509
# Epoch 00027: val_loss improved from 0.67621 to 0.67124, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6718 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.7489
# Epoch 28/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6706 - sparse_categorical_accuracy: 0.7499
# Epoch 00028: val_loss improved from 0.67124 to 0.66907, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6706 - sparse_categorical_accuracy: 0.7499 - val_loss: 0.6691 - val_sparse_categorical_accuracy: 0.7553
# Epoch 29/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6643 - sparse_categorical_accuracy: 0.7543
# Epoch 00029: val_loss did not improve from 0.66907
# 125/125 [==============================] - 38s 304ms/step - loss: 0.6643 - sparse_categorical_accuracy: 0.7543 - val_loss: 0.6715 - val_sparse_categorical_accuracy: 0.7542
# Epoch 30/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6617 - sparse_categorical_accuracy: 0.7538
# Epoch 00030: val_loss improved from 0.66907 to 0.66241, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.6617 - sparse_categorical_accuracy: 0.7538 - val_loss: 0.6624 - val_sparse_categorical_accuracy: 0.7504
# Epoch 31/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6579 - sparse_categorical_accuracy: 0.7566
# Epoch 00031: val_loss improved from 0.66241 to 0.66237, saving model to mymodel.h5
# 125/125 [==============================] - 39s 312ms/step - loss: 0.6579 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.6624 - val_sparse_categorical_accuracy: 0.7490
# Epoch 32/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6558 - sparse_categorical_accuracy: 0.7546
# Epoch 00032: val_loss improved from 0.66237 to 0.65565, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.6558 - sparse_categorical_accuracy: 0.7546 - val_loss: 0.6556 - val_sparse_categorical_accuracy: 0.7557
# Epoch 33/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6456 - sparse_categorical_accuracy: 0.7629
# Epoch 00033: val_loss did not improve from 0.65565
# 125/125 [==============================] - 38s 302ms/step - loss: 0.6456 - sparse_categorical_accuracy: 0.7629 - val_loss: 0.6596 - val_sparse_categorical_accuracy: 0.7513
# Epoch 34/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6486 - sparse_categorical_accuracy: 0.7589
# Epoch 00034: val_loss improved from 0.65565 to 0.64809, saving model to mymodel.h5
# 125/125 [==============================] - 38s 307ms/step - loss: 0.6486 - sparse_categorical_accuracy: 0.7589 - val_loss: 0.6481 - val_sparse_categorical_accuracy: 0.7599
# Epoch 35/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6453 - sparse_categorical_accuracy: 0.7615
# Epoch 00035: val_loss did not improve from 0.64809
# 125/125 [==============================] - 38s 303ms/step - loss: 0.6453 - sparse_categorical_accuracy: 0.7615 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.7582
# Epoch 36/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6471 - sparse_categorical_accuracy: 0.7605
# Epoch 00036: val_loss improved from 0.64809 to 0.64775, saving model to mymodel.h5
# 125/125 [==============================] - 38s 308ms/step - loss: 0.6471 - sparse_categorical_accuracy: 0.7605 - val_loss: 0.6477 - val_sparse_categorical_accuracy: 0.7595
# Epoch 37/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6401 - sparse_categorical_accuracy: 0.7626
# Epoch 00037: val_loss improved from 0.64775 to 0.64023, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.6401 - sparse_categorical_accuracy: 0.7626 - val_loss: 0.6402 - val_sparse_categorical_accuracy: 0.7591
# Epoch 38/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6277 - sparse_categorical_accuracy: 0.7672
# Epoch 00038: val_loss did not improve from 0.64023
# 125/125 [==============================] - 38s 302ms/step - loss: 0.6277 - sparse_categorical_accuracy: 0.7672 - val_loss: 0.6533 - val_sparse_categorical_accuracy: 0.7559
# Epoch 39/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6349 - sparse_categorical_accuracy: 0.7649
# Epoch 00039: val_loss improved from 0.64023 to 0.63872, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.6349 - sparse_categorical_accuracy: 0.7649 - val_loss: 0.6387 - val_sparse_categorical_accuracy: 0.7624
# Epoch 40/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6322 - sparse_categorical_accuracy: 0.7677
# Epoch 00040: val_loss improved from 0.63872 to 0.63344, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.6322 - sparse_categorical_accuracy: 0.7677 - val_loss: 0.6334 - val_sparse_categorical_accuracy: 0.7668
# Epoch 41/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6290 - sparse_categorical_accuracy: 0.7663
# Epoch 00041: val_loss improved from 0.63344 to 0.63120, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.6290 - sparse_categorical_accuracy: 0.7663 - val_loss: 0.6312 - val_sparse_categorical_accuracy: 0.7654
# Epoch 42/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6253 - sparse_categorical_accuracy: 0.7679
# Epoch 00042: val_loss did not improve from 0.63120
# 125/125 [==============================] - 38s 304ms/step - loss: 0.6253 - sparse_categorical_accuracy: 0.7679 - val_loss: 0.6388 - val_sparse_categorical_accuracy: 0.7689
# Epoch 43/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6295 - sparse_categorical_accuracy: 0.7674
# Epoch 00043: val_loss did not improve from 0.63120
# 125/125 [==============================] - 38s 302ms/step - loss: 0.6295 - sparse_categorical_accuracy: 0.7674 - val_loss: 0.6336 - val_sparse_categorical_accuracy: 0.7651
# Epoch 44/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6242 - sparse_categorical_accuracy: 0.7699
# Epoch 00044: val_loss did not improve from 0.63120
# 125/125 [==============================] - 38s 304ms/step - loss: 0.6242 - sparse_categorical_accuracy: 0.7699 - val_loss: 0.6340 - val_sparse_categorical_accuracy: 0.7647
# Epoch 45/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6219 - sparse_categorical_accuracy: 0.7700
# Epoch 00045: val_loss did not improve from 0.63120
# 125/125 [==============================] - 38s 303ms/step - loss: 0.6219 - sparse_categorical_accuracy: 0.7700 - val_loss: 0.6391 - val_sparse_categorical_accuracy: 0.7620
# Epoch 46/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6149 - sparse_categorical_accuracy: 0.7731
# Epoch 00046: val_loss improved from 0.63120 to 0.62393, saving model to mymodel.h5
# 125/125 [==============================] - 38s 307ms/step - loss: 0.6149 - sparse_categorical_accuracy: 0.7731 - val_loss: 0.6239 - val_sparse_categorical_accuracy: 0.7696
# Epoch 47/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6163 - sparse_categorical_accuracy: 0.7721
# Epoch 00047: val_loss improved from 0.62393 to 0.62391, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6163 - sparse_categorical_accuracy: 0.7721 - val_loss: 0.6239 - val_sparse_categorical_accuracy: 0.7687
# Epoch 48/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6135 - sparse_categorical_accuracy: 0.7744
# Epoch 00048: val_loss improved from 0.62391 to 0.62261, saving model to mymodel.h5
# 125/125 [==============================] - 39s 313ms/step - loss: 0.6135 - sparse_categorical_accuracy: 0.7744 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.7694
# Epoch 49/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6164 - sparse_categorical_accuracy: 0.7744
# Epoch 00049: val_loss did not improve from 0.62261
# 125/125 [==============================] - 38s 301ms/step - loss: 0.6164 - sparse_categorical_accuracy: 0.7744 - val_loss: 0.6239 - val_sparse_categorical_accuracy: 0.7706
# Epoch 50/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6100 - sparse_categorical_accuracy: 0.7759
# Epoch 00050: val_loss improved from 0.62261 to 0.62221, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6100 - sparse_categorical_accuracy: 0.7759 - val_loss: 0.6222 - val_sparse_categorical_accuracy: 0.7689
# Epoch 51/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6100 - sparse_categorical_accuracy: 0.7744
# Epoch 00051: val_loss improved from 0.62221 to 0.61912, saving model to mymodel.h5
# 125/125 [==============================] - 38s 308ms/step - loss: 0.6100 - sparse_categorical_accuracy: 0.7744 - val_loss: 0.6191 - val_sparse_categorical_accuracy: 0.7731
# Epoch 52/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6061 - sparse_categorical_accuracy: 0.7778
# Epoch 00052: val_loss improved from 0.61912 to 0.61588, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.6061 - sparse_categorical_accuracy: 0.7778 - val_loss: 0.6159 - val_sparse_categorical_accuracy: 0.7732
# Epoch 53/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6072 - sparse_categorical_accuracy: 0.7773
# Epoch 00053: val_loss did not improve from 0.61588
# 125/125 [==============================] - 38s 303ms/step - loss: 0.6072 - sparse_categorical_accuracy: 0.7773 - val_loss: 0.6187 - val_sparse_categorical_accuracy: 0.7662
# Epoch 54/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6029 - sparse_categorical_accuracy: 0.7759
# Epoch 00054: val_loss did not improve from 0.61588
# 125/125 [==============================] - 38s 304ms/step - loss: 0.6029 - sparse_categorical_accuracy: 0.7759 - val_loss: 0.6224 - val_sparse_categorical_accuracy: 0.7692
# Epoch 55/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6039 - sparse_categorical_accuracy: 0.7777
# Epoch 00055: val_loss improved from 0.61588 to 0.61208, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.6039 - sparse_categorical_accuracy: 0.7777 - val_loss: 0.6121 - val_sparse_categorical_accuracy: 0.7725
# Epoch 56/300
# 125/125 [==============================] - ETA: 0s - loss: 0.6027 - sparse_categorical_accuracy: 0.7774
# Epoch 00056: val_loss did not improve from 0.61208
# 125/125 [==============================] - 38s 304ms/step - loss: 0.6027 - sparse_categorical_accuracy: 0.7774 - val_loss: 0.6202 - val_sparse_categorical_accuracy: 0.7719
# Epoch 57/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5965 - sparse_categorical_accuracy: 0.7827
# Epoch 00057: val_loss improved from 0.61208 to 0.60711, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.5965 - sparse_categorical_accuracy: 0.7827 - val_loss: 0.6071 - val_sparse_categorical_accuracy: 0.7753
# Epoch 58/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5969 - sparse_categorical_accuracy: 0.7823
# Epoch 00058: val_loss did not improve from 0.60711
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5969 - sparse_categorical_accuracy: 0.7823 - val_loss: 0.6075 - val_sparse_categorical_accuracy: 0.7790
# Epoch 59/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5956 - sparse_categorical_accuracy: 0.7818
# Epoch 00059: val_loss did not improve from 0.60711
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5956 - sparse_categorical_accuracy: 0.7818 - val_loss: 0.6136 - val_sparse_categorical_accuracy: 0.7729
# Epoch 60/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5945 - sparse_categorical_accuracy: 0.7829
# Epoch 00060: val_loss did not improve from 0.60711
# 125/125 [==============================] - 38s 305ms/step - loss: 0.5945 - sparse_categorical_accuracy: 0.7829 - val_loss: 0.6118 - val_sparse_categorical_accuracy: 0.7757
# Epoch 61/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5936 - sparse_categorical_accuracy: 0.7828
# Epoch 00061: val_loss improved from 0.60711 to 0.60387, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5936 - sparse_categorical_accuracy: 0.7828 - val_loss: 0.6039 - val_sparse_categorical_accuracy: 0.7799
# Epoch 62/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5909 - sparse_categorical_accuracy: 0.7851
# Epoch 00062: val_loss improved from 0.60387 to 0.60101, saving model to mymodel.h5
# 125/125 [==============================] - 39s 312ms/step - loss: 0.5909 - sparse_categorical_accuracy: 0.7851 - val_loss: 0.6010 - val_sparse_categorical_accuracy: 0.7812
# Epoch 63/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5889 - sparse_categorical_accuracy: 0.7840
# Epoch 00063: val_loss did not improve from 0.60101
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5889 - sparse_categorical_accuracy: 0.7840 - val_loss: 0.6018 - val_sparse_categorical_accuracy: 0.7790
# Epoch 64/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5901 - sparse_categorical_accuracy: 0.7853
# Epoch 00064: val_loss improved from 0.60101 to 0.60031, saving model to mymodel.h5
# 125/125 [==============================] - 39s 313ms/step - loss: 0.5901 - sparse_categorical_accuracy: 0.7853 - val_loss: 0.6003 - val_sparse_categorical_accuracy: 0.7816
# Epoch 65/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5846 - sparse_categorical_accuracy: 0.7881
# Epoch 00065: val_loss did not improve from 0.60031
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5846 - sparse_categorical_accuracy: 0.7881 - val_loss: 0.6008 - val_sparse_categorical_accuracy: 0.7809
# Epoch 66/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5883 - sparse_categorical_accuracy: 0.7864
# Epoch 00066: val_loss did not improve from 0.60031
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5883 - sparse_categorical_accuracy: 0.7864 - val_loss: 0.6055 - val_sparse_categorical_accuracy: 0.7793
# Epoch 67/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5813 - sparse_categorical_accuracy: 0.7893
# Epoch 00067: val_loss improved from 0.60031 to 0.59412, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5813 - sparse_categorical_accuracy: 0.7893 - val_loss: 0.5941 - val_sparse_categorical_accuracy: 0.7832
# Epoch 68/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5859 - sparse_categorical_accuracy: 0.7856
# Epoch 00068: val_loss did not improve from 0.59412
# 125/125 [==============================] - 38s 305ms/step - loss: 0.5859 - sparse_categorical_accuracy: 0.7856 - val_loss: 0.5947 - val_sparse_categorical_accuracy: 0.7830
# Epoch 69/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5796 - sparse_categorical_accuracy: 0.7899
# Epoch 00069: val_loss did not improve from 0.59412
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5796 - sparse_categorical_accuracy: 0.7899 - val_loss: 0.6021 - val_sparse_categorical_accuracy: 0.7763
# Epoch 70/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5844 - sparse_categorical_accuracy: 0.7863
# Epoch 00070: val_loss improved from 0.59412 to 0.59193, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5844 - sparse_categorical_accuracy: 0.7863 - val_loss: 0.5919 - val_sparse_categorical_accuracy: 0.7853
# Epoch 71/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5745 - sparse_categorical_accuracy: 0.7910
# Epoch 00071: val_loss did not improve from 0.59193
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5745 - sparse_categorical_accuracy: 0.7910 - val_loss: 0.5927 - val_sparse_categorical_accuracy: 0.7818
# Epoch 72/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5720 - sparse_categorical_accuracy: 0.7941
# Epoch 00072: val_loss did not improve from 0.59193
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5720 - sparse_categorical_accuracy: 0.7941 - val_loss: 0.6125 - val_sparse_categorical_accuracy: 0.7765
# Epoch 73/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5765 - sparse_categorical_accuracy: 0.7925
# Epoch 00073: val_loss did not improve from 0.59193
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5765 - sparse_categorical_accuracy: 0.7925 - val_loss: 0.5994 - val_sparse_categorical_accuracy: 0.7795
# Epoch 74/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5798 - sparse_categorical_accuracy: 0.7888
# Epoch 00074: val_loss improved from 0.59193 to 0.58879, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.5798 - sparse_categorical_accuracy: 0.7888 - val_loss: 0.5888 - val_sparse_categorical_accuracy: 0.7822
# Epoch 75/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5716 - sparse_categorical_accuracy: 0.7938
# Epoch 00075: val_loss improved from 0.58879 to 0.58705, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.5716 - sparse_categorical_accuracy: 0.7938 - val_loss: 0.5870 - val_sparse_categorical_accuracy: 0.7870
# Epoch 76/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5674 - sparse_categorical_accuracy: 0.7965
# Epoch 00076: val_loss did not improve from 0.58705
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5674 - sparse_categorical_accuracy: 0.7965 - val_loss: 0.5929 - val_sparse_categorical_accuracy: 0.7837
# Epoch 77/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5697 - sparse_categorical_accuracy: 0.7925
# Epoch 00077: val_loss did not improve from 0.58705
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5697 - sparse_categorical_accuracy: 0.7925 - val_loss: 0.5946 - val_sparse_categorical_accuracy: 0.7832
# Epoch 78/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5717 - sparse_categorical_accuracy: 0.7921
# Epoch 00078: val_loss did not improve from 0.58705
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5717 - sparse_categorical_accuracy: 0.7921 - val_loss: 0.5919 - val_sparse_categorical_accuracy: 0.7837
# Epoch 79/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5693 - sparse_categorical_accuracy: 0.7929
# Epoch 00079: val_loss improved from 0.58705 to 0.58202, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5693 - sparse_categorical_accuracy: 0.7929 - val_loss: 0.5820 - val_sparse_categorical_accuracy: 0.7896
# Epoch 80/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5638 - sparse_categorical_accuracy: 0.7944
# Epoch 00080: val_loss did not improve from 0.58202
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5638 - sparse_categorical_accuracy: 0.7944 - val_loss: 0.5889 - val_sparse_categorical_accuracy: 0.7849
# Epoch 81/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5677 - sparse_categorical_accuracy: 0.7943
# Epoch 00081: val_loss did not improve from 0.58202
# 125/125 [==============================] - 38s 300ms/step - loss: 0.5677 - sparse_categorical_accuracy: 0.7943 - val_loss: 0.5839 - val_sparse_categorical_accuracy: 0.7875
# Epoch 82/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5637 - sparse_categorical_accuracy: 0.7929
# Epoch 00082: val_loss improved from 0.58202 to 0.58021, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.5637 - sparse_categorical_accuracy: 0.7929 - val_loss: 0.5802 - val_sparse_categorical_accuracy: 0.7883
# Epoch 83/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5640 - sparse_categorical_accuracy: 0.7976
# Epoch 00083: val_loss improved from 0.58021 to 0.57923, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5640 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.5792 - val_sparse_categorical_accuracy: 0.7883
# Epoch 84/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5618 - sparse_categorical_accuracy: 0.7953
# Epoch 00084: val_loss did not improve from 0.57923
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5618 - sparse_categorical_accuracy: 0.7953 - val_loss: 0.5891 - val_sparse_categorical_accuracy: 0.7868
# Epoch 85/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5627 - sparse_categorical_accuracy: 0.7964
# Epoch 00085: val_loss did not improve from 0.57923
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5627 - sparse_categorical_accuracy: 0.7964 - val_loss: 0.5819 - val_sparse_categorical_accuracy: 0.7883
# Epoch 86/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5595 - sparse_categorical_accuracy: 0.7966
# Epoch 00086: val_loss improved from 0.57923 to 0.57704, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5595 - sparse_categorical_accuracy: 0.7966 - val_loss: 0.5770 - val_sparse_categorical_accuracy: 0.7900
# Epoch 87/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5562 - sparse_categorical_accuracy: 0.7997
# Epoch 00087: val_loss did not improve from 0.57704
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5562 - sparse_categorical_accuracy: 0.7997 - val_loss: 0.5791 - val_sparse_categorical_accuracy: 0.7921
# Epoch 88/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5586 - sparse_categorical_accuracy: 0.7971
# Epoch 00088: val_loss did not improve from 0.57704
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5586 - sparse_categorical_accuracy: 0.7971 - val_loss: 0.5831 - val_sparse_categorical_accuracy: 0.7864
# Epoch 89/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5572 - sparse_categorical_accuracy: 0.7993
# Epoch 00089: val_loss improved from 0.57704 to 0.57476, saving model to mymodel.h5
# 125/125 [==============================] - 39s 313ms/step - loss: 0.5572 - sparse_categorical_accuracy: 0.7993 - val_loss: 0.5748 - val_sparse_categorical_accuracy: 0.7915
# Epoch 90/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5537 - sparse_categorical_accuracy: 0.8015
# Epoch 00090: val_loss did not improve from 0.57476
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5537 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.5763 - val_sparse_categorical_accuracy: 0.7917
# Epoch 91/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5599 - sparse_categorical_accuracy: 0.7961
# Epoch 00091: val_loss did not improve from 0.57476
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5599 - sparse_categorical_accuracy: 0.7961 - val_loss: 0.5770 - val_sparse_categorical_accuracy: 0.7879
# Epoch 92/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5533 - sparse_categorical_accuracy: 0.8013
# Epoch 00092: val_loss did not improve from 0.57476
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5533 - sparse_categorical_accuracy: 0.8013 - val_loss: 0.5774 - val_sparse_categorical_accuracy: 0.7919
# Epoch 93/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5456 - sparse_categorical_accuracy: 0.8009
# Epoch 00093: val_loss improved from 0.57476 to 0.57287, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.5456 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.5729 - val_sparse_categorical_accuracy: 0.7919
# Epoch 94/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5582 - sparse_categorical_accuracy: 0.7977
# Epoch 00094: val_loss did not improve from 0.57287
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5582 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.5773 - val_sparse_categorical_accuracy: 0.7929
# Epoch 95/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5463 - sparse_categorical_accuracy: 0.8021
# Epoch 00095: val_loss improved from 0.57287 to 0.57041, saving model to mymodel.h5
# 125/125 [==============================] - 39s 310ms/step - loss: 0.5463 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.5704 - val_sparse_categorical_accuracy: 0.7948
# Epoch 96/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5460 - sparse_categorical_accuracy: 0.8007
# Epoch 00096: val_loss did not improve from 0.57041
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5460 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.5876 - val_sparse_categorical_accuracy: 0.7868
# Epoch 97/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5551 - sparse_categorical_accuracy: 0.7981
# Epoch 00097: val_loss did not improve from 0.57041
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5551 - sparse_categorical_accuracy: 0.7981 - val_loss: 0.5709 - val_sparse_categorical_accuracy: 0.7913
# Epoch 98/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5497 - sparse_categorical_accuracy: 0.8015
# Epoch 00098: val_loss did not improve from 0.57041
# 125/125 [==============================] - 38s 305ms/step - loss: 0.5497 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.5762 - val_sparse_categorical_accuracy: 0.7921
# Epoch 99/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5483 - sparse_categorical_accuracy: 0.8001
# Epoch 00099: val_loss did not improve from 0.57041
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5483 - sparse_categorical_accuracy: 0.8001 - val_loss: 0.5768 - val_sparse_categorical_accuracy: 0.7877
# Epoch 100/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5442 - sparse_categorical_accuracy: 0.8046
# Epoch 00100: val_loss improved from 0.57041 to 0.56887, saving model to mymodel.h5
# 125/125 [==============================] - 38s 306ms/step - loss: 0.5442 - sparse_categorical_accuracy: 0.8046 - val_loss: 0.5689 - val_sparse_categorical_accuracy: 0.7952
# Epoch 101/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5437 - sparse_categorical_accuracy: 0.8034
# Epoch 00101: val_loss improved from 0.56887 to 0.56819, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.5437 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.5682 - val_sparse_categorical_accuracy: 0.7946
# Epoch 102/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5437 - sparse_categorical_accuracy: 0.8018
# Epoch 00102: val_loss improved from 0.56819 to 0.56631, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.5437 - sparse_categorical_accuracy: 0.8018 - val_loss: 0.5663 - val_sparse_categorical_accuracy: 0.7959
# Epoch 103/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5466 - sparse_categorical_accuracy: 0.8034
# Epoch 00103: val_loss did not improve from 0.56631
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5466 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.5670 - val_sparse_categorical_accuracy: 0.7950
# Epoch 104/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5387 - sparse_categorical_accuracy: 0.8058
# Epoch 00104: val_loss did not improve from 0.56631
# 125/125 [==============================] - 38s 305ms/step - loss: 0.5387 - sparse_categorical_accuracy: 0.8058 - val_loss: 0.5671 - val_sparse_categorical_accuracy: 0.7933
# Epoch 105/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5441 - sparse_categorical_accuracy: 0.8028
# Epoch 00105: val_loss did not improve from 0.56631
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5441 - sparse_categorical_accuracy: 0.8028 - val_loss: 0.5691 - val_sparse_categorical_accuracy: 0.7919
# Epoch 106/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5409 - sparse_categorical_accuracy: 0.8027
# Epoch 00106: val_loss improved from 0.56631 to 0.56547, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.5409 - sparse_categorical_accuracy: 0.8027 - val_loss: 0.5655 - val_sparse_categorical_accuracy: 0.7963
# Epoch 107/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5407 - sparse_categorical_accuracy: 0.8036
# Epoch 00107: val_loss improved from 0.56547 to 0.56398, saving model to mymodel.h5
# 125/125 [==============================] - 39s 312ms/step - loss: 0.5407 - sparse_categorical_accuracy: 0.8036 - val_loss: 0.5640 - val_sparse_categorical_accuracy: 0.7954
# Epoch 108/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5399 - sparse_categorical_accuracy: 0.8046
# Epoch 00108: val_loss did not improve from 0.56398
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5399 - sparse_categorical_accuracy: 0.8046 - val_loss: 0.5653 - val_sparse_categorical_accuracy: 0.7938
# Epoch 109/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5402 - sparse_categorical_accuracy: 0.8035
# Epoch 00109: val_loss did not improve from 0.56398
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5402 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.5651 - val_sparse_categorical_accuracy: 0.7940
# Epoch 110/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5354 - sparse_categorical_accuracy: 0.8063
# Epoch 00110: val_loss did not improve from 0.56398
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.8063 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.7946
# Epoch 111/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5356 - sparse_categorical_accuracy: 0.8074
# Epoch 00111: val_loss did not improve from 0.56398
# 125/125 [==============================] - 37s 299ms/step - loss: 0.5356 - sparse_categorical_accuracy: 0.8074 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.7938
# Epoch 112/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5392 - sparse_categorical_accuracy: 0.8055
# Epoch 00112: val_loss improved from 0.56398 to 0.56088, saving model to mymodel.h5
# 125/125 [==============================] - 39s 308ms/step - loss: 0.5392 - sparse_categorical_accuracy: 0.8055 - val_loss: 0.5609 - val_sparse_categorical_accuracy: 0.7938
# Epoch 113/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5302 - sparse_categorical_accuracy: 0.8081
# Epoch 00113: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5302 - sparse_categorical_accuracy: 0.8081 - val_loss: 0.5631 - val_sparse_categorical_accuracy: 0.7950
# Epoch 114/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5391 - sparse_categorical_accuracy: 0.8059
# Epoch 00114: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5391 - sparse_categorical_accuracy: 0.8059 - val_loss: 0.5723 - val_sparse_categorical_accuracy: 0.7883
# Epoch 115/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5354 - sparse_categorical_accuracy: 0.8051
# Epoch 00115: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.5689 - val_sparse_categorical_accuracy: 0.7921
# Epoch 116/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5308 - sparse_categorical_accuracy: 0.8061
# Epoch 00116: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 301ms/step - loss: 0.5308 - sparse_categorical_accuracy: 0.8061 - val_loss: 0.5616 - val_sparse_categorical_accuracy: 0.7955
# Epoch 117/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5327 - sparse_categorical_accuracy: 0.8108
# Epoch 00117: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5327 - sparse_categorical_accuracy: 0.8108 - val_loss: 0.5704 - val_sparse_categorical_accuracy: 0.7908
# Epoch 118/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5298 - sparse_categorical_accuracy: 0.8079
# Epoch 00118: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5298 - sparse_categorical_accuracy: 0.8079 - val_loss: 0.5667 - val_sparse_categorical_accuracy: 0.7933
# Epoch 119/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5328 - sparse_categorical_accuracy: 0.8084
# Epoch 00119: val_loss did not improve from 0.56088
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5328 - sparse_categorical_accuracy: 0.8084 - val_loss: 0.5633 - val_sparse_categorical_accuracy: 0.7940
# Epoch 120/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5288 - sparse_categorical_accuracy: 0.8103
# Epoch 00120: val_loss improved from 0.56088 to 0.55807, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.5288 - sparse_categorical_accuracy: 0.8103 - val_loss: 0.5581 - val_sparse_categorical_accuracy: 0.7961
# Epoch 121/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5305 - sparse_categorical_accuracy: 0.8073
# Epoch 00121: val_loss did not improve from 0.55807
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5305 - sparse_categorical_accuracy: 0.8073 - val_loss: 0.5591 - val_sparse_categorical_accuracy: 0.7955
# Epoch 122/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5276 - sparse_categorical_accuracy: 0.8095
# Epoch 00122: val_loss did not improve from 0.55807
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5276 - sparse_categorical_accuracy: 0.8095 - val_loss: 0.5598 - val_sparse_categorical_accuracy: 0.7944
# Epoch 123/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5301 - sparse_categorical_accuracy: 0.8084
# Epoch 00123: val_loss did not improve from 0.55807
# 125/125 [==============================] - 38s 304ms/step - loss: 0.5301 - sparse_categorical_accuracy: 0.8084 - val_loss: 0.5595 - val_sparse_categorical_accuracy: 0.7940
# Epoch 124/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5253 - sparse_categorical_accuracy: 0.8094
# Epoch 00124: val_loss improved from 0.55807 to 0.55790, saving model to mymodel.h5
# 125/125 [==============================] - 39s 313ms/step - loss: 0.5253 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.5579 - val_sparse_categorical_accuracy: 0.7973
# Epoch 125/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5270 - sparse_categorical_accuracy: 0.8091
# Epoch 00125: val_loss did not improve from 0.55790
# 125/125 [==============================] - 37s 298ms/step - loss: 0.5270 - sparse_categorical_accuracy: 0.8091 - val_loss: 0.5880 - val_sparse_categorical_accuracy: 0.7887
# Epoch 126/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5235 - sparse_categorical_accuracy: 0.8108
# Epoch 00126: val_loss did not improve from 0.55790
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5235 - sparse_categorical_accuracy: 0.8108 - val_loss: 0.5619 - val_sparse_categorical_accuracy: 0.7976
# Epoch 127/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5231 - sparse_categorical_accuracy: 0.8133
# Epoch 00127: val_loss improved from 0.55790 to 0.55679, saving model to mymodel.h5
# 125/125 [==============================] - 39s 312ms/step - loss: 0.5231 - sparse_categorical_accuracy: 0.8133 - val_loss: 0.5568 - val_sparse_categorical_accuracy: 0.7984
# Epoch 128/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5263 - sparse_categorical_accuracy: 0.8093
# Epoch 00128: val_loss improved from 0.55679 to 0.55433, saving model to mymodel.h5
# 125/125 [==============================] - 39s 311ms/step - loss: 0.5263 - sparse_categorical_accuracy: 0.8093 - val_loss: 0.5543 - val_sparse_categorical_accuracy: 0.7976
# Epoch 129/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5284 - sparse_categorical_accuracy: 0.8083
# Epoch 00129: val_loss did not improve from 0.55433
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5284 - sparse_categorical_accuracy: 0.8083 - val_loss: 0.5594 - val_sparse_categorical_accuracy: 0.7954
# Epoch 130/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5247 - sparse_categorical_accuracy: 0.8109
# Epoch 00130: val_loss did not improve from 0.55433
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5247 - sparse_categorical_accuracy: 0.8109 - val_loss: 0.5688 - val_sparse_categorical_accuracy: 0.7936
# Epoch 131/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5233 - sparse_categorical_accuracy: 0.8100
# Epoch 00131: val_loss did not improve from 0.55433
# 125/125 [==============================] - 38s 302ms/step - loss: 0.5233 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.5654 - val_sparse_categorical_accuracy: 0.7936
# Epoch 132/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5221 - sparse_categorical_accuracy: 0.8124
# Epoch 00132: val_loss improved from 0.55433 to 0.55384, saving model to mymodel.h5
# 125/125 [==============================] - 39s 314ms/step - loss: 0.5221 - sparse_categorical_accuracy: 0.8124 - val_loss: 0.5538 - val_sparse_categorical_accuracy: 0.7992
# Epoch 133/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5175 - sparse_categorical_accuracy: 0.8124
# Epoch 00133: val_loss did not improve from 0.55384
# 125/125 [==============================] - 38s 305ms/step - loss: 0.5175 - sparse_categorical_accuracy: 0.8124 - val_loss: 0.5571 - val_sparse_categorical_accuracy: 0.7990
# Epoch 134/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5205 - sparse_categorical_accuracy: 0.8131
# Epoch 00134: val_loss did not improve from 0.55384
# 125/125 [==============================] - 38s 303ms/step - loss: 0.5205 - sparse_categorical_accuracy: 0.8131 - val_loss: 0.5589 - val_sparse_categorical_accuracy: 0.7954
# Epoch 135/300
# 125/125 [==============================] - ETA: 0s - loss: 0.5177 - sparse_categorical_accuracy: 0.8149
# Epoch 00135: val_loss did not improve from 0.55384
# ...
# Epoch 00254: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 304ms/step - loss: 0.4548 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.5334 - val_sparse_categorical_accuracy: 0.8074
# Epoch 255/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4567 - sparse_categorical_accuracy: 0.8367
# Epoch 00255: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4567 - sparse_categorical_accuracy: 0.8367 - val_loss: 0.5368 - val_sparse_categorical_accuracy: 0.8051
# Epoch 256/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4546 - sparse_categorical_accuracy: 0.8380
# Epoch 00256: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4546 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.5356 - val_sparse_categorical_accuracy: 0.8096
# Epoch 257/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4542 - sparse_categorical_accuracy: 0.8391
# Epoch 00257: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4542 - sparse_categorical_accuracy: 0.8391 - val_loss: 0.5343 - val_sparse_categorical_accuracy: 0.8064
# Epoch 258/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4534 - sparse_categorical_accuracy: 0.8383
# Epoch 00258: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 304ms/step - loss: 0.4534 - sparse_categorical_accuracy: 0.8383 - val_loss: 0.5394 - val_sparse_categorical_accuracy: 0.8039
# Epoch 259/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4544 - sparse_categorical_accuracy: 0.8404
# Epoch 00259: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 305ms/step - loss: 0.4544 - sparse_categorical_accuracy: 0.8404 - val_loss: 0.5494 - val_sparse_categorical_accuracy: 0.7986
# Epoch 260/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4545 - sparse_categorical_accuracy: 0.8407
# Epoch 00260: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 301ms/step - loss: 0.4545 - sparse_categorical_accuracy: 0.8407 - val_loss: 0.5340 - val_sparse_categorical_accuracy: 0.8058
# Epoch 261/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4566 - sparse_categorical_accuracy: 0.8384
# Epoch 00261: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 305ms/step - loss: 0.4566 - sparse_categorical_accuracy: 0.8384 - val_loss: 0.5378 - val_sparse_categorical_accuracy: 0.8053
# Epoch 262/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4549 - sparse_categorical_accuracy: 0.8389
# Epoch 00262: val_loss did not improve from 0.53035
# 125/125 [==============================] - 37s 299ms/step - loss: 0.4549 - sparse_categorical_accuracy: 0.8389 - val_loss: 0.5377 - val_sparse_categorical_accuracy: 0.8077
# Epoch 263/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4554 - sparse_categorical_accuracy: 0.8397
# Epoch 00263: val_loss did not improve from 0.53035
# 125/125 [==============================] - 39s 308ms/step - loss: 0.4554 - sparse_categorical_accuracy: 0.8397 - val_loss: 0.5371 - val_sparse_categorical_accuracy: 0.8075
# Epoch 264/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4548 - sparse_categorical_accuracy: 0.8378
# Epoch 00264: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4548 - sparse_categorical_accuracy: 0.8378 - val_loss: 0.5382 - val_sparse_categorical_accuracy: 0.8058
# Epoch 265/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4574 - sparse_categorical_accuracy: 0.8368
# Epoch 00265: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 304ms/step - loss: 0.4574 - sparse_categorical_accuracy: 0.8368 - val_loss: 0.5413 - val_sparse_categorical_accuracy: 0.8045
# Epoch 266/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4516 - sparse_categorical_accuracy: 0.8403
# Epoch 00266: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 300ms/step - loss: 0.4516 - sparse_categorical_accuracy: 0.8403 - val_loss: 0.5398 - val_sparse_categorical_accuracy: 0.8047
# Epoch 267/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4593 - sparse_categorical_accuracy: 0.8380
# Epoch 00267: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4593 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.5351 - val_sparse_categorical_accuracy: 0.8053
# Epoch 268/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4460 - sparse_categorical_accuracy: 0.8430
# Epoch 00268: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4460 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.5351 - val_sparse_categorical_accuracy: 0.8049
# Epoch 269/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4476 - sparse_categorical_accuracy: 0.8401
# Epoch 00269: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4476 - sparse_categorical_accuracy: 0.8401 - val_loss: 0.5370 - val_sparse_categorical_accuracy: 0.8104
# Epoch 270/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4534 - sparse_categorical_accuracy: 0.8387
# Epoch 00270: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 305ms/step - loss: 0.4534 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.5418 - val_sparse_categorical_accuracy: 0.8045
# Epoch 271/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4478 - sparse_categorical_accuracy: 0.8423
# Epoch 00271: val_loss did not improve from 0.53035
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4478 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.5423 - val_sparse_categorical_accuracy: 0.8030
# Epoch 272/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4505 - sparse_categorical_accuracy: 0.8405
# Epoch 00272: val_loss improved from 0.53035 to 0.52993, saving model to mymodel.h5
# 125/125 [==============================] - 39s 313ms/step - loss: 0.4505 - sparse_categorical_accuracy: 0.8405 - val_loss: 0.5299 - val_sparse_categorical_accuracy: 0.8077
# Epoch 273/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4454 - sparse_categorical_accuracy: 0.8438
# Epoch 00273: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 305ms/step - loss: 0.4454 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.5376 - val_sparse_categorical_accuracy: 0.8072
# Epoch 274/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4488 - sparse_categorical_accuracy: 0.8407
# Epoch 00274: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4488 - sparse_categorical_accuracy: 0.8407 - val_loss: 0.5314 - val_sparse_categorical_accuracy: 0.8068
# Epoch 275/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4476 - sparse_categorical_accuracy: 0.8396
# Epoch 00275: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 301ms/step - loss: 0.4476 - sparse_categorical_accuracy: 0.8396 - val_loss: 0.5381 - val_sparse_categorical_accuracy: 0.8083
# Epoch 276/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4459 - sparse_categorical_accuracy: 0.8423
# Epoch 00276: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4459 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.5337 - val_sparse_categorical_accuracy: 0.8077
# Epoch 277/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4487 - sparse_categorical_accuracy: 0.8419
# Epoch 00277: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4487 - sparse_categorical_accuracy: 0.8419 - val_loss: 0.5375 - val_sparse_categorical_accuracy: 0.8054
# Epoch 278/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4462 - sparse_categorical_accuracy: 0.8421
# Epoch 00278: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4462 - sparse_categorical_accuracy: 0.8421 - val_loss: 0.5348 - val_sparse_categorical_accuracy: 0.8074
# Epoch 279/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4467 - sparse_categorical_accuracy: 0.8421
# Epoch 00279: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4467 - sparse_categorical_accuracy: 0.8421 - val_loss: 0.5403 - val_sparse_categorical_accuracy: 0.8093
# Epoch 280/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4424 - sparse_categorical_accuracy: 0.8438
# Epoch 00280: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 304ms/step - loss: 0.4424 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.5397 - val_sparse_categorical_accuracy: 0.8083
# Epoch 281/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4470 - sparse_categorical_accuracy: 0.8404
# Epoch 00281: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 301ms/step - loss: 0.4470 - sparse_categorical_accuracy: 0.8404 - val_loss: 0.5363 - val_sparse_categorical_accuracy: 0.8079
# Epoch 282/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4456 - sparse_categorical_accuracy: 0.8437
# Epoch 00282: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 303ms/step - loss: 0.4456 - sparse_categorical_accuracy: 0.8437 - val_loss: 0.5458 - val_sparse_categorical_accuracy: 0.8016
# Epoch 283/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4446 - sparse_categorical_accuracy: 0.8433
# Epoch 00283: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4446 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.5448 - val_sparse_categorical_accuracy: 0.8034
# Epoch 284/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4452 - sparse_categorical_accuracy: 0.8418
# Epoch 00284: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4452 - sparse_categorical_accuracy: 0.8418 - val_loss: 0.5343 - val_sparse_categorical_accuracy: 0.8081
# Epoch 285/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4484 - sparse_categorical_accuracy: 0.8433
# Epoch 00285: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 301ms/step - loss: 0.4484 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.5444 - val_sparse_categorical_accuracy: 0.8016
# Epoch 286/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4393 - sparse_categorical_accuracy: 0.8447
# Epoch 00286: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 304ms/step - loss: 0.4393 - sparse_categorical_accuracy: 0.8447 - val_loss: 0.5330 - val_sparse_categorical_accuracy: 0.8085
# Epoch 287/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4486 - sparse_categorical_accuracy: 0.8393
# Epoch 00287: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 300ms/step - loss: 0.4486 - sparse_categorical_accuracy: 0.8393 - val_loss: 0.5305 - val_sparse_categorical_accuracy: 0.8074
# Epoch 288/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4400 - sparse_categorical_accuracy: 0.8464
# Epoch 00288: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 304ms/step - loss: 0.4400 - sparse_categorical_accuracy: 0.8464 - val_loss: 0.5303 - val_sparse_categorical_accuracy: 0.8104
# Epoch 289/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4411 - sparse_categorical_accuracy: 0.8423
# Epoch 00289: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4411 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.5402 - val_sparse_categorical_accuracy: 0.8077
# Epoch 290/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4406 - sparse_categorical_accuracy: 0.8429
# Epoch 00290: val_loss did not improve from 0.52993
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4406 - sparse_categorical_accuracy: 0.8429 - val_loss: 0.5352 - val_sparse_categorical_accuracy: 0.8100
# Epoch 291/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4383 - sparse_categorical_accuracy: 0.8443
# Epoch 00291: val_loss improved from 0.52993 to 0.52896, saving model to mymodel.h5
# 125/125 [==============================] - 39s 309ms/step - loss: 0.4383 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.5290 - val_sparse_categorical_accuracy: 0.8102
# Epoch 292/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4464 - sparse_categorical_accuracy: 0.8429
# Epoch 00292: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 305ms/step - loss: 0.4464 - sparse_categorical_accuracy: 0.8429 - val_loss: 0.5388 - val_sparse_categorical_accuracy: 0.8054
# Epoch 293/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4405 - sparse_categorical_accuracy: 0.8453
# Epoch 00293: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4405 - sparse_categorical_accuracy: 0.8453 - val_loss: 0.5335 - val_sparse_categorical_accuracy: 0.8108
# Epoch 294/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4397 - sparse_categorical_accuracy: 0.8431
# Epoch 00294: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 301ms/step - loss: 0.4397 - sparse_categorical_accuracy: 0.8431 - val_loss: 0.5337 - val_sparse_categorical_accuracy: 0.8070
# Epoch 295/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4400 - sparse_categorical_accuracy: 0.8443
# Epoch 00295: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4400 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.5311 - val_sparse_categorical_accuracy: 0.8089
# Epoch 296/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4419 - sparse_categorical_accuracy: 0.8421
# Epoch 00296: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 305ms/step - loss: 0.4419 - sparse_categorical_accuracy: 0.8421 - val_loss: 0.5314 - val_sparse_categorical_accuracy: 0.8068
# Epoch 297/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4407 - sparse_categorical_accuracy: 0.8439
# Epoch 00297: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 307ms/step - loss: 0.4407 - sparse_categorical_accuracy: 0.8439 - val_loss: 0.5369 - val_sparse_categorical_accuracy: 0.8087
# Epoch 298/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4406 - sparse_categorical_accuracy: 0.8454
# Epoch 00298: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4406 - sparse_categorical_accuracy: 0.8454 - val_loss: 0.5336 - val_sparse_categorical_accuracy: 0.8085
# Epoch 299/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4340 - sparse_categorical_accuracy: 0.8466
# Epoch 00299: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4340 - sparse_categorical_accuracy: 0.8466 - val_loss: 0.5348 - val_sparse_categorical_accuracy: 0.8087
# Epoch 300/300
# 125/125 [==============================] - ETA: 0s - loss: 0.4392 - sparse_categorical_accuracy: 0.8427
# Epoch 00300: val_loss did not improve from 0.52896
# 125/125 [==============================] - 38s 302ms/step - loss: 0.4392 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.5300 - val_sparse_categorical_accuracy: 0.8074

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo multiple                  21
# _________________________________________________________________
# vgg19 (Model)                (None, 16, 16, 512)       20024384
# _________________________________________________________________
# global_average_pooling2d (Gl multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2101248
# _________________________________________________________________
# dense_1 (Dense)              multiple                  16781312
# _________________________________________________________________
# dense_2 (Dense)              multiple                  4097000
# _________________________________________________________________
# dense_3 (Dense)              multiple                  500500
# _________________________________________________________________
# dense_4 (Dense)              multiple                  50100
# _________________________________________________________________
# dense_5 (Dense)              multiple                  505
# =================================================================
# Total params: 43,555,070
# Trainable params: 23,530,671
# Non-trainable params: 20,024,399
# _________________________________________________________________

# %% [markdown]
# ## Saving the model for backup

# %%
model.save('model2_VGG19_untunable.h5')
model.save('model3_VGG19_untunable.hdf5')

# %%
## load the history data if we stopped the model suddenly 

#log_data = pd.read_csv('training.log', sep=',', engine='python')

# %%
##model2 = tf.keras.models.load_model('../input/testmodel2/model2_VGG19_untunable.h5')

# %%
##model.save('model2.h5')

# %%
##model.save('model.hdf5')

# %%
## load the history data if we stopped the model suddenly 

history_frame = pd.read_csv('training.log', sep=',', engine='python')


##history_frame = pd.read_csv('../input/testmodel2/training.log', sep=',', engine='python')

# %% [markdown]
# ## Plot the History of the model

# %%
# create learning curves to evaluate model performance
#history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['sparse_categorical_accuracy', 'val_sparse_categorical_accuracy']].plot();

# %% [markdown]
# # Some conclusions
#
# The maximum sparse_categorical_accuracy is around = 0.84
#
# The maximum val_sparse_categorical_accuracy is around = 0.81
#
# Which is not bad without balancing the data but we have also augmentation on the fly
#
# In this case , this time there is no over fitting in the trained model, the training accuracy and the validation one are close to each other. But the over all performance is not that good and need to be enhanced using balancing and filltering the dataset

# %% [markdown]
# # predict the test photo

# %%
# this code will convert our test image data to a float32 
def to_float32(image, label):
    return tf.cast(image, tf.float32), label

# %%
test_ds = get_test_dataset(ordered=True) 
test_ds = test_ds.map(to_float32)

print('Computing predictions...')
##test_images_ds = get_test_dataset()
test_images_ds = test_ds.map(lambda image, idnum: image)
probabilities = model.predict(test_images_ds)
predictions = np.argmax(probabilities, axis=-1)
print(predictions)
# Out:
# Computing predictions...
# [4]

# %% [markdown]
# # Getting the test label in a list

# %%
# load our validation dataset labels
y_test = []
##x_test = []

validation_dataset = get_validation_dataset()
validation_dataset = validation_dataset.unbatch()##.batch(1)
for image, label in validation_dataset:
    ##x_test.append(image.numpy())
    y_test.append(label.numpy())

# %%
# output deleted because it is too big
y_test

# %%
len(y_test)
# Out:
# 5352

# %% [markdown]
# # Brief exploratory data analysis (EDA)
# First we'll print out the shapes and labels for a sample of each of our three datasets:

# %%
'''
print("Training data shapes:")
for image, label in get_training_dataset().take(3):
    print(image.numpy().shape, label.numpy().shape)
print("Training data label examples:", label.numpy())
print("Validation data shapes:")
for image, label in get_validation_dataset().take(3):
    print(image.numpy().shape, label.numpy().shape)
print("Validation data label examples:", label.numpy())
print("Test data shapes:")
for image, idnum in get_test_dataset().take(3):
    print(image.numpy().shape, idnum.numpy().shape)
print("Test data IDs:", idnum.numpy().astype('U')) # U=unicode string
'''

# %% [markdown]
# # Getting the prediction of the validation set

# %%
validation_dataset = get_validation_dataset()

probabilities = model.predict(validation_dataset)
predictions = np.argmax(probabilities, axis=-1)

print(predictions)
# Out:
# [3 1 2 ... 3 3 1]

# %%
'''
def get_train_dataset():
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True)  

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

'''

# %%
'''
train_dataset = get_train_dataset()

train_probabilities = model.predict(train_dataset)
train_predictions = np.argmax(train_probabilities, axis=-1)

print(train_predictions)
'''
# Out:
# [3 1 4 ... 3 4 4]

# %%
'''
# load our validation dataset for EDA
y_train = []
##x_test = []

train_dataset = get_train_dataset()
train_dataset = train_dataset.unbatch()##.batch(1)
for image, label in train_dataset:
    ##x_test.append(image.numpy())
    y_train.append(label.numpy())
'''

# %%
##len(y_train)
# Out:
# 16045

# %% [markdown]
# # Some libraries for plotting

# %%
import tempfile

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Plotting the confusion Matrix
#
# Calculating the Recall and the Precision (Calculated manually after getting the concept for multicalasses classification)

# %%
from sklearn.metrics import confusion_matrix



def plot_cm(labels, predictions):
      cm = confusion_matrix(labels, predictions)
      print(cm)
      plt.figure(figsize=(5,5))
      sns.heatmap(cm, annot=True, fmt="d")
      plt.title('Confusion matrix')
      plt.ylabel('Actual label')
      plt.xlabel('Predicted label')


      rows = np.sum(cm, axis = 1) 
      cols = np.sum(cm, axis = 0) 
      recall_labels = []
      Precision_labels = []

      for i in range(len(CLASSES)):
        recall_labels.append(cm[i][i]/rows[i])
        Precision_labels.append(cm[i][i]/cols[i])
        
      print('recall labels = ')
      print(recall_labels)
      print("")
    
      print('Precision labels = ')
      print(Precision_labels)
      print("")

      MACRO_AVERAGING_Recall = np.sum(recall_labels)/len(CLASSES)
      MACRO_AVERAGING_Precision = np.sum(Precision_labels)/len(CLASSES)

      print('MACRO AVERAGING Recall = ')
      print(MACRO_AVERAGING_Recall)
      print("")
    
      print('MACRO AVERAGING Precision = ')
      print(MACRO_AVERAGING_Precision)
      print("")
        
  



'''
labels = [0, 1, 2, 3, 4]

cm = confusion_matrix(y_test, predictions)

print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
'''
# Out:
# "\nlabels = [0, 1, 2, 3, 4]\n\ncm = confusion_matrix(y_test, predictions)\n\nprint(cm)\nfig = plt.figure()\nax = fig.add_subplot(111)\ncax = ax.matshow(cm)\nplt.title('Confusion matrix of the classifier')\nfig.colorbar(cax)\nax.set_xticklabels([''] + labels)\nax.set_yticklabels([''] + labels)\nplt.xlabel('Predicted')\nplt.ylabel('True')\nplt.show()\n"

# %%
plot_cm(y_test, predictions)
# Out:
# [[  15   30   30  143   31]
#  [  21   66   41  368   54]
#  [  20   75   58  384   91]
#  [ 142  350  333 2046  388]
#  [  28   74   86  405   73]]
# recall labels =
# [0.060240963855421686, 0.12, 0.09235668789808917, 0.6277999386314821, 0.10960960960960961]
#
# Precision labels =
# [0.06637168141592921, 0.11092436974789915, 0.10583941605839416, 0.6114763897190676, 0.11459968602825746]
#
# MACRO AVERAGING Recall =
# 0.2020014399989205
#
# MACRO AVERAGING Precision =
# 0.20184230859390953

# %%
##manually getting the Precision and recall but we but them up in the function of plot cm
'''
rows = np.sum(cm, axis = 1) 
cols = np.sum(cm, axis = 0) 
recall_labels = []
Precision_labels = []

for i in range(len(CLASSES)):
    recall_labels.append(cm[i][i]/rows[i])
    Precision_labels.append(cm[i][i]/cols[i])
    
print(recall_labels)
print(Precision_labels)

MACRO_AVERAGING_Recall = np.sum(recall_labels)/len(CLASSES)
MACRO_AVERAGING_Precision = np.sum(Precision_labels)/len(CLASSES)

print(MACRO_AVERAGING_Recall)
print(MACRO_AVERAGING_Precision)
'''
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in long_scalars

# %% [markdown]
# # Plotting the ROC Curve
#
# 1st trying for Binary classification

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing  import label_binarize
# from scipy import interp

n_classes = len(CLASSES)

# Binarize the output 
true_labels_l_b = label_binarize(y_test, classes=range(n_classes))
# Y_pred_b = label_binarize(Y_pred, classes=CLASSES)
Y_pred_b = label_binarize(predictions, classes=range(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(true_labels_l_b[:,i], Y_pred_b[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(true_labels_l_b.ravel(), Y_pred_b.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])



#Plot of a ROC curve for a specific class

plt.figure()
lw = 2
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # 2nd  or multiclasses classification

# %%
import itertools

target_names = ['(CBB)','Brown Streak Disease (CBSD) ','Green Mottle (CGM) ','Mosaic Disease (CMD) ','Healthy ']

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize = (10,10))

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = itertools.cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(target_names[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
