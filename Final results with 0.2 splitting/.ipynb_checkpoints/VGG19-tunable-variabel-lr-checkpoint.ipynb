# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import math, re, os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from kaggle_datasets import KaggleDatasets
from tensorflow import keras
from functools import partial
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

##import tensorflow.keras.backend as K

from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization, MaxPool2D
from keras.optimizers import SGD
import keras

import h5py

from keras.callbacks import ModelCheckpoint

from keras import metrics


print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.2.0

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Device: grpc://10.0.0.2:8470
# Number of replicas: 8

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path('cassava-leaf-disease-classification')     

##../input/cassava-leaf-disease-classification

BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [512, 512]
CLASSES = ['0', '1', '2', '3', '4']
##EPOCHS = 300
EPOCHS = 100

# %%
BATCH_SIZE
# Out:
# 128

# %%
df = pd.read_csv(GCS_PATH + '/train.csv')

# %%
# Images and Labels
X = df.loc[:,'image_id']
y = df.loc[:,'label']
count_labels=y.values

# %%
# COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
# print("Normal images count in training set: " + str(COUNT_NORMAL))

# COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
# print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
CBB = 0
CBSD = 0
CGM = 0
CMD = 0
Healthy = 0

for label in count_labels:
    if label == 0:
        CBB += 1
    elif label == 1:
        CBSD  += 1
    elif label == 2:
        CGM  += 1
    elif label == 3:
        CMD  += 1
    else:
        Healthy +=1


print("The number of CBB = ",CBB )
print("The number of CBSD = ",CBSD)
print("The number of CGM = ",CGM )
print("The number of CMD = ",CMD)
print("The number of Healthy = ",Healthy)
# Out:
# The number of CBB =  1087
# The number of CBSD =  2189
# The number of CGM =  2386
# The number of CMD =  13158
# The number of Healthy =  2577

# %%
def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example, labeled):
    tfrecord_format = {
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.int64)
    } if labeled else {
        "image": tf.io.FixedLenFeature([], tf.string),
        "image_name": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    if labeled:
        label = tf.cast(example['target'], tf.int32)
        return image, label
    idnum = example['image_name']
    return image, idnum

def load_dataset(filenames, labeled=True, ordered=False):
    ignore_order = tf.data.Options() ## Turn off optimization 
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed, ## Turn off optimization (or ordered)
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(partial(read_tfrecord, labeled=labeled), num_parallel_calls=AUTOTUNE)
    return dataset

# %%
def data_augment(image, label):
    # Thanks to the dataset.prefetch(AUTO) statement in the following function this happens essentially for free on TPU. 
    # Data pipeline code is executed on the "CPU" part of the TPU while the TPU itself is computing gradients.
    ##if label !=3:
    choice = np.random.randint(5)
    if choice == 0:
        image = tf.image.flip_left_right(image)
    elif choice == 1:
        image = tf.image.flip_up_down(image)
    elif choice == 2:
        image = tf.image.random_flip_left_right(image)
    elif choice == 3:
        image = tf.image.random_flip_up_down(image)
    else:
        image = tf.image.rot90(image)
    
    ##else:
    ##    return image, label
    
    return image, label
'''
elif choice == 5:
        image = tf.image.transpose(image)
    elif choice == 6:
        image = tf.image.adjust_brightness(image, delta=0.1)
    elif choice == 7:
        image = tf.image.adjust_contrast(image, 2)
    elif choice == 8:
        image = tf.image.adjust_gamma(image, 0.2)
    elif choice == 9:
        image = tf.image.random_brightness(image, 0.2)
    elif choice == 10:
        image = tf.image.random_contrast(image, 0.2, 0.5)
    elif choice == 11:
        image = tf.image.rgb_to_grayscale(image)
    else:
        image = tf.image.adjust_hue(image, 0.2)
'''
# Out:
# '\nelif choice == 5:\n        image = tf.image.transpose(image)\n    elif choice == 6:\n        image = tf.image.adjust_brightness(image, delta=0.1)\n    elif choice == 7:\n        image = tf.image.adjust_contrast(image, 2)\n    elif choice == 8:\n        image = tf.image.adjust_gamma(image, 0.2)\n    elif choice == 9:\n        image = tf.image.random_brightness(image, 0.2)\n    elif choice == 10:\n        image = tf.image.random_contrast(image, 0.2, 0.5)\n    elif choice == 11:\n        image = tf.image.rgb_to_grayscale(image)\n    else:\n        image = tf.image.adjust_hue(image, 0.2)\n'

# %%
TRAINING_FILENAMES, VALID_FILENAMES = train_test_split(
    tf.io.gfile.glob(GCS_PATH + '/train_tfrecords/ld_train*.tfrec'),
    test_size=0.2, random_state=5
)

TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test_tfrecords/ld_test*.tfrec')

# %%
VALID_FILENAMES
# Out:
# ['gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train05-1338.tfrec',
#  'gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train01-1338.tfrec',
#  'gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train07-1338.tfrec',
#  'gs://kds-0ec1dec9f628bce2bc810157442805632bd221934a9e1921da420af8/train_tfrecords/ld_train02-1338.tfrec']

# %%
def get_training_dataset():
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True)  
    dataset = dataset.map(data_augment, num_parallel_calls=AUTOTUNE)  
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

def get_validation_dataset(ordered=False):
    dataset = load_dataset(VALID_FILENAMES, labeled=True, ordered=ordered)
    ##dataset = dataset.map(data_augment, num_parallel_calls=AUTOTUNE) 
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

def get_test_dataset(ordered=False):
    dataset = load_dataset(TEST_FILENAMES, labeled=False, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

# %%
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALID_FILENAMES)
NUM_TEST_IMAGES = count_data_items(TEST_FILENAMES)

print('Dataset: {} training images, {} validation images, {} (unlabeled) test images'.format(
    NUM_TRAINING_IMAGES, NUM_VALIDATION_IMAGES, NUM_TEST_IMAGES))
# Out:
# Dataset: 16045 training images, 5352 validation images, 1 (unlabeled) test images

# %%
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-5, 
    decay_steps=10000, 
    decay_rate=0.9)

# %%
# example of loading the vgg19 model
from keras.applications.vgg19 import VGG19
# load model
model = VGG19()
# summarize the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 5s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.applications.vgg19 import preprocess_input

#tf.keras.applications.vgg19.preprocess_input


with strategy.scope():       
    ##img_adjust_layer = tf.keras.layers.Lambda(tf.keras.applications.vgg16.preprocess_input, input_shape=[512,512, 3])
    
    base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_tensor= None,
    input_shape=[512,512, 3],
    pooling=None,
    classes=5,
    classifier_activation="softmax")
    
    base_model.trainable = True
    
    
    model = tf.keras.Sequential([
        tf.keras.layers.BatchNormalization(renorm=True),
        ##img_adjust_layer,
        base_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=4096,activation="relu"),
        tf.keras.layers.Dense(units=4096,activation="relu"),
        tf.keras.layers.Dense(units=5, activation="softmax") 
        
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_scheduler, epsilon=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy'])
        

'''
        metrics2=['categorical_accuracy',
                           tf.keras.metrics.Precision(name='Precision'),
                           tf.keras.metrics.Recall(name='Recall')])
                           
                           'sparse_categorical_accuracy'
                           metrics=['sparse_categorical_accuracy'])
                            metrics=['sparse_categorical_accuracy',tf.keras.metrics.AUC()])
'''
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# "\n        metrics2=['categorical_accuracy',\n                           tf.keras.metrics.Precision(name='Precision'),\n                           tf.keras.metrics.Recall(name='Recall')])\n                           \n                           'sparse_categorical_accuracy'\n                           metrics=['sparse_categorical_accuracy'])\n                            metrics=['sparse_categorical_accuracy',tf.keras.metrics.AUC()])\n"

# %%
# load data
train_dataset = get_training_dataset()
valid_dataset = get_validation_dataset()

# %%
from keras.callbacks import CSVLogger

##csv_logger = CSVLogger('training.log', separator=',', append=False)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

keras_callbacks   = [EarlyStopping(monitor='val_loss', patience=35, mode='min', min_delta=0.0001),
    ModelCheckpoint('mymodel.h5', monitor='val_loss', verbose=1,
    save_best_only=True, save_weights_only=True, mode='auto', period=1),
    CSVLogger('training.log', separator=',', append=False)
    
]

##save_best_only=True

# %%
STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE
VALID_STEPS = NUM_VALIDATION_IMAGES // BATCH_SIZE

history = model.fit(train_dataset, 
                    steps_per_epoch=STEPS_PER_EPOCH, 
                    epochs=EPOCHS,
                    validation_data=valid_dataset,
                    validation_steps=VALID_STEPS,
                    callbacks=keras_callbacks)
                   

##model.save('mymodel.h5')
# Out:
# Epoch 1/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.5868 - loss: 1.1838
# Epoch 00001: val_loss improved from inf to 1.03517, saving model to mymodel.h5
# 125/125 [==============================] - 67s 533ms/step - sparse_categorical_accuracy: 0.5868 - loss: 1.1838 - val_sparse_categorical_accuracy: 0.6103 - val_loss: 1.0352
# Epoch 2/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.6764 - loss: 0.8495
# Epoch 00002: val_loss improved from 1.03517 to 0.68813, saving model to mymodel.h5
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.6764 - loss: 0.8495 - val_sparse_categorical_accuracy: 0.7477 - val_loss: 0.6881
# Epoch 3/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.7691 - loss: 0.6357
# Epoch 00003: val_loss improved from 0.68813 to 0.59918, saving model to mymodel.h5
# 125/125 [==============================] - 55s 438ms/step - sparse_categorical_accuracy: 0.7691 - loss: 0.6357 - val_sparse_categorical_accuracy: 0.7934 - val_loss: 0.5992
# Epoch 4/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8058 - loss: 0.5436
# Epoch 00004: val_loss improved from 0.59918 to 0.51025, saving model to mymodel.h5
# 125/125 [==============================] - 55s 436ms/step - sparse_categorical_accuracy: 0.8058 - loss: 0.5436 - val_sparse_categorical_accuracy: 0.8209 - val_loss: 0.5103
# Epoch 5/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8257 - loss: 0.4936
# Epoch 00005: val_loss improved from 0.51025 to 0.50707, saving model to mymodel.h5
# 125/125 [==============================] - 55s 438ms/step - sparse_categorical_accuracy: 0.8257 - loss: 0.4936 - val_sparse_categorical_accuracy: 0.8276 - val_loss: 0.5071
# Epoch 6/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8337 - loss: 0.4748
# Epoch 00006: val_loss improved from 0.50707 to 0.45514, saving model to mymodel.h5
# 125/125 [==============================] - 55s 437ms/step - sparse_categorical_accuracy: 0.8337 - loss: 0.4748 - val_sparse_categorical_accuracy: 0.8495 - val_loss: 0.4551
# Epoch 7/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8423 - loss: 0.4525
# Epoch 00007: val_loss did not improve from 0.45514
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.8423 - loss: 0.4525 - val_sparse_categorical_accuracy: 0.8396 - val_loss: 0.4672
# Epoch 8/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8500 - loss: 0.4380
# Epoch 00008: val_loss improved from 0.45514 to 0.44580, saving model to mymodel.h5
# 125/125 [==============================] - 55s 440ms/step - sparse_categorical_accuracy: 0.8500 - loss: 0.4380 - val_sparse_categorical_accuracy: 0.8514 - val_loss: 0.4458
# Epoch 9/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8526 - loss: 0.4242
# Epoch 00009: val_loss improved from 0.44580 to 0.44442, saving model to mymodel.h5
# 125/125 [==============================] - 55s 439ms/step - sparse_categorical_accuracy: 0.8526 - loss: 0.4242 - val_sparse_categorical_accuracy: 0.8540 - val_loss: 0.4444
# Epoch 10/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8602 - loss: 0.4029
# Epoch 00010: val_loss did not improve from 0.44442
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.8602 - loss: 0.4029 - val_sparse_categorical_accuracy: 0.8470 - val_loss: 0.4450
# Epoch 11/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8614 - loss: 0.3960
# Epoch 00011: val_loss improved from 0.44442 to 0.44072, saving model to mymodel.h5
# 125/125 [==============================] - 55s 439ms/step - sparse_categorical_accuracy: 0.8614 - loss: 0.3960 - val_sparse_categorical_accuracy: 0.8527 - val_loss: 0.4407
# Epoch 12/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8681 - loss: 0.3850
# Epoch 00012: val_loss improved from 0.44072 to 0.41926, saving model to mymodel.h5
# 125/125 [==============================] - 55s 439ms/step - sparse_categorical_accuracy: 0.8681 - loss: 0.3850 - val_sparse_categorical_accuracy: 0.8579 - val_loss: 0.4193
# Epoch 13/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8714 - loss: 0.3739
# Epoch 00013: val_loss did not improve from 0.41926
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.8714 - loss: 0.3739 - val_sparse_categorical_accuracy: 0.8571 - val_loss: 0.4294
# Epoch 14/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8753 - loss: 0.3636
# Epoch 00014: val_loss improved from 0.41926 to 0.40940, saving model to mymodel.h5
# 125/125 [==============================] - 55s 438ms/step - sparse_categorical_accuracy: 0.8753 - loss: 0.3636 - val_sparse_categorical_accuracy: 0.8601 - val_loss: 0.4094
# Epoch 15/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8794 - loss: 0.3554
# Epoch 00015: val_loss improved from 0.40940 to 0.39711, saving model to mymodel.h5
# 125/125 [==============================] - 55s 440ms/step - sparse_categorical_accuracy: 0.8794 - loss: 0.3554 - val_sparse_categorical_accuracy: 0.8657 - val_loss: 0.3971
# Epoch 16/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8814 - loss: 0.3410
# Epoch 00016: val_loss improved from 0.39711 to 0.39200, saving model to mymodel.h5
# 125/125 [==============================] - 55s 441ms/step - sparse_categorical_accuracy: 0.8814 - loss: 0.3410 - val_sparse_categorical_accuracy: 0.8689 - val_loss: 0.3920
# Epoch 17/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8843 - loss: 0.3355
# Epoch 00017: val_loss improved from 0.39200 to 0.39086, saving model to mymodel.h5
# 125/125 [==============================] - 55s 441ms/step - sparse_categorical_accuracy: 0.8843 - loss: 0.3355 - val_sparse_categorical_accuracy: 0.8660 - val_loss: 0.3909
# Epoch 18/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8842 - loss: 0.3338
# Epoch 00018: val_loss did not improve from 0.39086
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.8842 - loss: 0.3338 - val_sparse_categorical_accuracy: 0.8670 - val_loss: 0.4070
# Epoch 19/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8853 - loss: 0.3282
# Epoch 00019: val_loss improved from 0.39086 to 0.38236, saving model to mymodel.h5
# 125/125 [==============================] - 55s 439ms/step - sparse_categorical_accuracy: 0.8853 - loss: 0.3282 - val_sparse_categorical_accuracy: 0.8687 - val_loss: 0.3824
# Epoch 20/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8924 - loss: 0.3134
# Epoch 00020: val_loss did not improve from 0.38236
# 125/125 [==============================] - 54s 431ms/step - sparse_categorical_accuracy: 0.8924 - loss: 0.3134 - val_sparse_categorical_accuracy: 0.8668 - val_loss: 0.4035
# Epoch 21/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8914 - loss: 0.3093
# Epoch 00021: val_loss did not improve from 0.38236
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.8914 - loss: 0.3093 - val_sparse_categorical_accuracy: 0.8697 - val_loss: 0.3916
# Epoch 22/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8924 - loss: 0.3142
# Epoch 00022: val_loss did not improve from 0.38236
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.8924 - loss: 0.3142 - val_sparse_categorical_accuracy: 0.8678 - val_loss: 0.3964
# Epoch 23/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8969 - loss: 0.2961
# Epoch 00023: val_loss did not improve from 0.38236
# 125/125 [==============================] - 54s 431ms/step - sparse_categorical_accuracy: 0.8969 - loss: 0.2961 - val_sparse_categorical_accuracy: 0.8714 - val_loss: 0.3847
# Epoch 24/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9009 - loss: 0.2802
# Epoch 00024: val_loss improved from 0.38236 to 0.37338, saving model to mymodel.h5
# 125/125 [==============================] - 55s 441ms/step - sparse_categorical_accuracy: 0.9009 - loss: 0.2802 - val_sparse_categorical_accuracy: 0.8760 - val_loss: 0.3734
# Epoch 25/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8995 - loss: 0.2821
# Epoch 00025: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.8995 - loss: 0.2821 - val_sparse_categorical_accuracy: 0.8735 - val_loss: 0.3785
# Epoch 26/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9050 - loss: 0.2741
# Epoch 00026: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9050 - loss: 0.2741 - val_sparse_categorical_accuracy: 0.8735 - val_loss: 0.3871
# Epoch 27/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9083 - loss: 0.2602
# Epoch 00027: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.9083 - loss: 0.2602 - val_sparse_categorical_accuracy: 0.8721 - val_loss: 0.3926
# Epoch 28/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9110 - loss: 0.2535
# Epoch 00028: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.9110 - loss: 0.2535 - val_sparse_categorical_accuracy: 0.8672 - val_loss: 0.3938
# Epoch 29/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9089 - loss: 0.2557
# Epoch 00029: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9089 - loss: 0.2557 - val_sparse_categorical_accuracy: 0.8714 - val_loss: 0.4013
# Epoch 30/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9150 - loss: 0.2413
# Epoch 00030: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9150 - loss: 0.2413 - val_sparse_categorical_accuracy: 0.8756 - val_loss: 0.3965
# Epoch 31/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9133 - loss: 0.2467
# Epoch 00031: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9133 - loss: 0.2467 - val_sparse_categorical_accuracy: 0.8356 - val_loss: 0.4919
# Epoch 32/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9201 - loss: 0.2298
# Epoch 00032: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.9201 - loss: 0.2298 - val_sparse_categorical_accuracy: 0.8679 - val_loss: 0.4075
# Epoch 33/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9246 - loss: 0.2177
# Epoch 00033: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9246 - loss: 0.2177 - val_sparse_categorical_accuracy: 0.8723 - val_loss: 0.4031
# Epoch 34/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9250 - loss: 0.2116
# Epoch 00034: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 432ms/step - sparse_categorical_accuracy: 0.9250 - loss: 0.2116 - val_sparse_categorical_accuracy: 0.8628 - val_loss: 0.4487
# Epoch 35/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9224 - loss: 0.2190
# Epoch 00035: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9224 - loss: 0.2190 - val_sparse_categorical_accuracy: 0.8720 - val_loss: 0.4022
# Epoch 36/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9303 - loss: 0.1993
# Epoch 00036: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9303 - loss: 0.1993 - val_sparse_categorical_accuracy: 0.8765 - val_loss: 0.3939
# Epoch 37/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9337 - loss: 0.1893
# Epoch 00037: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 432ms/step - sparse_categorical_accuracy: 0.9337 - loss: 0.1893 - val_sparse_categorical_accuracy: 0.8685 - val_loss: 0.4405
# Epoch 38/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9371 - loss: 0.1799
# Epoch 00038: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 431ms/step - sparse_categorical_accuracy: 0.9371 - loss: 0.1799 - val_sparse_categorical_accuracy: 0.8681 - val_loss: 0.4530
# Epoch 39/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9423 - loss: 0.1719
# Epoch 00039: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9423 - loss: 0.1719 - val_sparse_categorical_accuracy: 0.8634 - val_loss: 0.4758
# Epoch 40/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9398 - loss: 0.1772
# Epoch 00040: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9398 - loss: 0.1772 - val_sparse_categorical_accuracy: 0.8537 - val_loss: 0.5038
# Epoch 41/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9455 - loss: 0.1564
# Epoch 00041: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9455 - loss: 0.1564 - val_sparse_categorical_accuracy: 0.8649 - val_loss: 0.4717
# Epoch 42/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9511 - loss: 0.1445
# Epoch 00042: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9511 - loss: 0.1445 - val_sparse_categorical_accuracy: 0.8605 - val_loss: 0.4788
# Epoch 43/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9537 - loss: 0.1357
# Epoch 00043: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9537 - loss: 0.1357 - val_sparse_categorical_accuracy: 0.8622 - val_loss: 0.4764
# Epoch 44/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9564 - loss: 0.1267
# Epoch 00044: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9564 - loss: 0.1267 - val_sparse_categorical_accuracy: 0.8630 - val_loss: 0.4798
# Epoch 45/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9554 - loss: 0.1309
# Epoch 00045: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 432ms/step - sparse_categorical_accuracy: 0.9554 - loss: 0.1309 - val_sparse_categorical_accuracy: 0.8624 - val_loss: 0.5209
# Epoch 46/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9589 - loss: 0.1211
# Epoch 00046: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9589 - loss: 0.1211 - val_sparse_categorical_accuracy: 0.8594 - val_loss: 0.5156
# Epoch 47/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9618 - loss: 0.1125
# Epoch 00047: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.9618 - loss: 0.1125 - val_sparse_categorical_accuracy: 0.8390 - val_loss: 0.5818
# Epoch 48/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9633 - loss: 0.1091
# Epoch 00048: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 434ms/step - sparse_categorical_accuracy: 0.9633 - loss: 0.1091 - val_sparse_categorical_accuracy: 0.8609 - val_loss: 0.5176
# Epoch 49/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9727 - loss: 0.0854
# Epoch 00049: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9727 - loss: 0.0854 - val_sparse_categorical_accuracy: 0.8558 - val_loss: 0.5499
# Epoch 50/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9740 - loss: 0.0809
# Epoch 00050: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 432ms/step - sparse_categorical_accuracy: 0.9740 - loss: 0.0809 - val_sparse_categorical_accuracy: 0.8678 - val_loss: 0.5438
# Epoch 51/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9760 - loss: 0.0767
# Epoch 00051: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 435ms/step - sparse_categorical_accuracy: 0.9760 - loss: 0.0767 - val_sparse_categorical_accuracy: 0.8653 - val_loss: 0.5955
# Epoch 52/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9651 - loss: 0.1060
# Epoch 00052: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 432ms/step - sparse_categorical_accuracy: 0.9651 - loss: 0.1060 - val_sparse_categorical_accuracy: 0.8369 - val_loss: 0.6523
# Epoch 53/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9766 - loss: 0.0689
# Epoch 00053: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9766 - loss: 0.0689 - val_sparse_categorical_accuracy: 0.8653 - val_loss: 0.5759
# Epoch 54/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9853 - loss: 0.0526
# Epoch 00054: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 432ms/step - sparse_categorical_accuracy: 0.9853 - loss: 0.0526 - val_sparse_categorical_accuracy: 0.8521 - val_loss: 0.6917
# Epoch 55/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9793 - loss: 0.0618
# Epoch 00055: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 430ms/step - sparse_categorical_accuracy: 0.9793 - loss: 0.0618 - val_sparse_categorical_accuracy: 0.8569 - val_loss: 0.5996
# Epoch 56/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9793 - loss: 0.0635
# Epoch 00056: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 433ms/step - sparse_categorical_accuracy: 0.9793 - loss: 0.0635 - val_sparse_categorical_accuracy: 0.8664 - val_loss: 0.6279
# Epoch 57/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9903 - loss: 0.0377
# Epoch 00057: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 431ms/step - sparse_categorical_accuracy: 0.9903 - loss: 0.0377 - val_sparse_categorical_accuracy: 0.8498 - val_loss: 0.6774
# Epoch 58/100
# 125/125 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9784 - loss: 0.0665
# Epoch 00058: val_loss did not improve from 0.37338
# 125/125 [==============================] - 54s 431ms/step - sparse_categorical_accuracy: 0.9784 - loss: 0.0665 - val_sparse_categorical_accuracy: 0.8605 - val_loss: 0.6371
# Epoch 59/100
#  21/125 [====>.........................] - ETA: 38s - sparse_categorical_accuracy: 0.9870 - loss: 0.0447
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-6fcd2af41338> in <module>
#       7                     validation_data=valid_dataset,
#       8                     validation_steps=VALID_STEPS,
# ----> 9                     callbacks=keras_callbacks)
#      10
#      11
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     853                 context.async_wait()
#     854               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 855               callbacks.on_train_batch_end(step, logs)
#     856         epoch_logs = copy.copy(logs)
#     857
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     387     """
#     388     if self._should_call_train_batch_hooks:
# --> 389       logs = self._process_logs(logs)
#     390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _process_logs(self, logs)
#     263     """Turns tensors into numpy arrays or Python scalars."""
#     264     if logs:
# --> 265       return tf_utils.to_numpy_or_python_type(logs)
#     266     return {}
#     267
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#     522
# --> 523   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     524
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     517   def _to_single_numpy_or_python_type(t):
#     518     if isinstance(t, ops.Tensor):
# --> 519       x = t.numpy()
#     520       return x.item() if np.ndim(x) == 0 else x
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#     959     """
#     960     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 961     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     962     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     963
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo multiple                  21
# _________________________________________________________________
# vgg19 (Model)                (None, 16, 16, 512)       20024384
# _________________________________________________________________
# global_average_pooling2d (Gl multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2101248
# _________________________________________________________________
# dense_1 (Dense)              multiple                  16781312
# _________________________________________________________________
# dense_2 (Dense)              multiple                  20485
# =================================================================
# Total params: 38,927,450
# Trainable params: 38,927,435
# Non-trainable params: 15
# _________________________________________________________________

# %%
model.save('model2_VGG19_untunable.h5')
model.save('model3_VGG19_untunable.hdf5')

# %%
## load the history data if we stopped the model suddenly 

#log_data = pd.read_csv('training.log', sep=',', engine='python')

# %%
##model2 = tf.keras.models.load_model('../input/testmodel2/model2_VGG19_untunable.h5')

# %%
##model.save('model2.h5')

# %%
##model.save('model.hdf5')

# %%
## load the history data if we stopped the model suddenly 

history_frame = pd.read_csv('training.log', sep=',', engine='python')


##history_frame = pd.read_csv('../input/testmodel2/training.log', sep=',', engine='python')

# %%
# create learning curves to evaluate model performance
#history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['sparse_categorical_accuracy', 'val_sparse_categorical_accuracy']].plot();

# %%
# this code will convert our test image data to a float32 
def to_float32(image, label):
    return tf.cast(image, tf.float32), label

# %%
test_ds = get_test_dataset(ordered=True) 
test_ds = test_ds.map(to_float32)

print('Computing predictions...')
##test_images_ds = get_test_dataset()
test_images_ds = test_ds.map(lambda image, idnum: image)
probabilities = model.predict(test_images_ds)
predictions = np.argmax(probabilities, axis=-1)
print(predictions)
# Out:
# Computing predictions...
# [4]

# %%
# load our validation dataset labels
y_test = []
##x_test = []

validation_dataset = get_validation_dataset()
validation_dataset = validation_dataset.unbatch()##.batch(1)
for image, label in validation_dataset:
    ##x_test.append(image.numpy())
    y_test.append(label.numpy())

# %%
y_test
# Out:
# [0,
#  3,
#  2,
#  3,
#  4,
#  1,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  1,
#  4,
#  1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  1,
#  4,
#  3,
#  3,
#  1,
#  3,
#  0,
#  3,
#  3,
#  3,
#  0,
#  2,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  2,
#  0,
#  2,
#  3,
#  3,
#  4,
#  1,
#  2,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  1,
#  2,
#  3,
#  3,
#  4,
#  0,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  4,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  0,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  1,
#  4,
#  3,
#  3,
#  2,
#  3,
#  4,
#  2,
#  3,
#  4,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  0,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  2,
#  4,
#  2,
#  3,
#  4,
#  3,
#  2,
#  3,
#  3,
#  4,
#  1,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  1,
#  3,
#  2,
#  3,
#  0,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  0,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  1,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  4,
#  0,
#  4,
#  3,
#  0,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  1,
#  3,
#  0,
#  3,
#  3,
#  1,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  1,
#  1,
#  3,
#  4,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  0,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  0,
#  0,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  0,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  4,
#  4,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  2,
#  4,
#  1,
#  3,
#  4,
#  3,
#  4,
#  3,
#  2,
#  0,
#  1,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  0,
#  3,
#  0,
#  1,
#  4,
#  1,
#  0,
#  1,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  0,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  1,
#  2,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  0,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  0,
#  1,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  0,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  3,
#  2,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  1,
#  0,
#  3,
#  3,
#  3,
#  0,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  1,
#  2,
#  3,
#  3,
#  2,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  0,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  1,
#  3,
#  0,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  3,
#  1,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  3,
#  4,
#  3,
#  0,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  1,
#  3,
#  4,
#  2,
#  2,
#  4,
#  3,
#  4,
#  3,
#  4,
#  2,
#  3,
#  4,
#  3,
#  2,
#  1,
#  3,
#  4,
#  4,
#  3,
#  3,
#  1,
#  3,
#  2,
#  4,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  4,
#  0,
#  1,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  0,
#  4,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  0,
#  4,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  3,
#  3,
#  3,
#  2,
#  2,
#  0,
#  3,
#  3,
#  4,
#  3,
#  1,
#  4,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  1,
#  3,
#  4,
#  2,
#  3,
#  3,
#  0,
#  3,
#  4,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  4,
#  0,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  1,
#  3,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  1,
#  0,
#  4,
#  4,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  0,
#  4,
#  3,
#  4,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  3,
#  4,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  4,
#  1,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  1,
#  3,
#  0,
#  4,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  0,
#  4,
#  3,
#  1,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  4,
#  3,
#  0,
#  3,
#  3,
#  4,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  4,
#  4,
#  4,
#  3,
#  3,
#  2,
#  3,
#  4,
#  ...]

# %%
len(y_test)
# Out:
# 5352

# %%
'''
print("Training data shapes:")
for image, label in get_training_dataset().take(3):
    print(image.numpy().shape, label.numpy().shape)
print("Training data label examples:", label.numpy())
print("Validation data shapes:")
for image, label in get_validation_dataset().take(3):
    print(image.numpy().shape, label.numpy().shape)
print("Validation data label examples:", label.numpy())
print("Test data shapes:")
for image, idnum in get_test_dataset().take(3):
    print(image.numpy().shape, idnum.numpy().shape)
print("Test data IDs:", idnum.numpy().astype('U')) # U=unicode string
'''

# %%
validation_dataset = get_validation_dataset()

probabilities = model.predict(validation_dataset)
predictions = np.argmax(probabilities, axis=-1)

print(predictions)
# Out:
# [3 1 2 ... 3 4 0]

# %%
'''
def get_train_dataset():
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True)  

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

'''

# %%
'''
train_dataset = get_train_dataset()

train_probabilities = model.predict(train_dataset)
train_predictions = np.argmax(train_probabilities, axis=-1)

print(train_predictions)
'''
# Out:
# [3 1 4 ... 3 4 4]

# %%
'''
# load our validation dataset for EDA
y_train = []
##x_test = []

train_dataset = get_train_dataset()
train_dataset = train_dataset.unbatch()##.batch(1)
for image, label in train_dataset:
    ##x_test.append(image.numpy())
    y_train.append(label.numpy())
'''

# %%
##len(y_train)
# Out:
# 16045

# %%
import tempfile

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import confusion_matrix



def plot_cm(labels, predictions):
      cm = confusion_matrix(labels, predictions)
      print(cm)
      plt.figure(figsize=(5,5))
      sns.heatmap(cm, annot=True, fmt="d")
      plt.title('Confusion matrix')
      plt.ylabel('Actual label')
      plt.xlabel('Predicted label')


      rows = np.sum(cm, axis = 1) 
      cols = np.sum(cm, axis = 0) 
      recall_labels = []
      Precision_labels = []

      for i in range(len(CLASSES)):
        recall_labels.append(cm[i][i]/rows[i])
        Precision_labels.append(cm[i][i]/cols[i])
        
      print('recall labels = ')
      print(recall_labels)
      print("")
    
      print('Precision labels = ')
      print(Precision_labels)
      print("")

      MACRO_AVERAGING_Recall = np.sum(recall_labels)/len(CLASSES)
      MACRO_AVERAGING_Precision = np.sum(Precision_labels)/len(CLASSES)

      print('MACRO AVERAGING Recall = ')
      print(MACRO_AVERAGING_Recall)
      print("")
    
      print('MACRO AVERAGING Precision = ')
      print(MACRO_AVERAGING_Precision)
      print("")
        
  



'''
labels = [0, 1, 2, 3, 4]

cm = confusion_matrix(y_test, predictions)

print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
'''
# Out:
# "\nlabels = [0, 1, 2, 3, 4]\n\ncm = confusion_matrix(y_test, predictions)\n\nprint(cm)\nfig = plt.figure()\nax = fig.add_subplot(111)\ncax = ax.matshow(cm)\nplt.title('Confusion matrix of the classifier')\nfig.colorbar(cax)\nax.set_xticklabels([''] + labels)\nax.set_yticklabels([''] + labels)\nplt.xlabel('Predicted')\nplt.ylabel('True')\nplt.show()\n"

# %%
plot_cm(y_test, predictions)
# Out:
# [[  13   31   27  143   35]
#  [  14   85   64  319   68]
#  [  15   52  115  365   81]
#  [  50  313  391 2059  446]
#  [  10   59   69  410  118]]
# recall labels =
# [0.05220883534136546, 0.15454545454545454, 0.18312101910828024, 0.631788892298251, 0.17717717717717718]
#
# Precision labels =
# [0.12745098039215685, 0.1574074074074074, 0.17267267267267267, 0.6246966019417476, 0.15775401069518716]
#
# MACRO AVERAGING Recall =
# 0.2397682756941057
#
# MACRO AVERAGING Precision =
# 0.24799633462183435

# %%
##manually getting the Precision and recall but we but them up in the function of plot cm
'''
rows = np.sum(cm, axis = 1) 
cols = np.sum(cm, axis = 0) 
recall_labels = []
Precision_labels = []

for i in range(len(CLASSES)):
    recall_labels.append(cm[i][i]/rows[i])
    Precision_labels.append(cm[i][i]/cols[i])
    
print(recall_labels)
print(Precision_labels)

MACRO_AVERAGING_Recall = np.sum(recall_labels)/len(CLASSES)
MACRO_AVERAGING_Precision = np.sum(Precision_labels)/len(CLASSES)

print(MACRO_AVERAGING_Recall)
print(MACRO_AVERAGING_Precision)
'''
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in long_scalars

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp[i], tp[i], _ = sklearn.metrics.roc_curve(labels, predictions)

  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.xlim([-0.5,20])
  plt.ylim([80,100.5])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
plot_roc("Train Baseline", y_train, train_predictions)
plot_roc("Test Baseline", y_test, predictions, color=colors[0], linestyle='--')
plt.legend(loc='lower right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-24bc8ab2f0f4> in <module>
# ----> 1 plot_roc("Train Baseline", y_train, train_predictions)
#       2 plot_roc("Test Baseline", y_test, predictions, color=colors[0], linestyle='--')
#       3 plt.legend(loc='lower right')
#
# NameError: name 'y_train' is not defined

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing  import label_binarize
# from scipy import interp

n_classes = len(CLASSES)

# Binarize the output 
true_labels_l_b = label_binarize(y_test, classes=range(n_classes))
# Y_pred_b = label_binarize(Y_pred, classes=CLASSES)
Y_pred_b = label_binarize(predictions, classes=range(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(true_labels_l_b[:,i], Y_pred_b[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(true_labels_l_b.ravel(), Y_pred_b.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])



#Plot of a ROC curve for a specific class

plt.figure()
lw = 2
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
import itertools

target_names = ['(CBB)','Brown Streak Disease (CBSD) ','Green Mottle (CGM) ','Mosaic Disease (CMD) ','Healthy ']

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize = (10,10))

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = itertools.cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(target_names[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
